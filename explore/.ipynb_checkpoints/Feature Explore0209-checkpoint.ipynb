# %%
# 导包
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
import jieba

import collections
import os

# %%
# 函数定义
from collections import Counter
from snownlp import SnowNLP

def merge(path, fileName):
    trainName = '../models/__models__/{}_{}.csv'.format(path, fileName)
    testName = trainName.replace('train', 'test')
    train = pd.read_csv(trainName)
    test = pd.read_csv(testName)
    data = pd.concat([train, test])
    return data

def read_map(filename):
    with open(Configure.root_data_path + filename, encoding='utf-8') as f:
        dictionary = dict()
        for line in f.readlines():
            line = line.strip().split(' ')
            dictionary[line[0]] = line[1]
        return dictionary

def read_file_word2dict(filename):
    with open(filename, 'r') as f:
        dictionary = dict()
        for line in f.readlines():
            line = line.strip().split(' ')
            for word in line:
                if word not in dictionary:
                    dictionary[word] = len(dictionary) + 1
        return dictionary
    
def read_file_word2set(filename, encoding = 'utf-8'):
    with open(filename, 'r', encoding = encoding) as f:
        dictionary = set()
        for line in f.readlines():
            line = line.strip().split(' ')
            for word in line:
                dictionary.add(word)
        return dictionary

def get_neg_words(data_df, stop_set = set(), feature = 'words', label = 'Score'):
    data_df_neg = data_df[data_df[label] == 1]
    return get_words(data_df_neg, stop_set = stop_set, feature = feature)

def get_keywords(data_df, stop_set = set(), feature = 'key_word', label = -1):
    dictionary = []
    score = data_df['Score'].values
    for i, word in enumerate(data_df[feature].values):
        word = str(word)
        if len(stop_set) == 0:
            if word != 'nan' and score[i] == label:
                dictionary.append(word)
        else:
            if word != 'nan' and score[i] == label and word not in stop_set:
                dictionary.append(word)
    return dictionary

def get_words(data_df, stop_set = set(), feature = 'words'):
    data_df = data_df[feature].values
    dictionary = []
    for sent in data_df:
        sent = sent[1:-1]
        sent = sent.split(';')
        for word in sent:
            if len(stop_set) == 0:
                if word != '':
                    dictionary.append(word)
            else:
                if word != '' and word not in stop_set:
                    dictionary.append(word)
    return dictionary

def build_dataset(words, vocabulary_size = 5000):
    from collections import Counter
    count = [['UNK', -1]]
    count.extend(Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary


def senti_snownlp(dicuss):
    if dicuss == '': return 0.5
    return SnowNLP(dicuss).sentiments

def clean_str(x, stop_word = '，'):
    words = list(jieba.cut(x))
    strbuild = '['
    for word in words:
        if word != stop_word:
            strbuild += word + ';'
    if ';' in strbuild: strbuild = strbuild[:-1]
    strbuild += ']'
    return strbuild    

def clean_str(words, stop_list):
    words = words[1:-1]
    words = words.split(';')
    strbuild = '['
    for word in words:
        if word not in stop_list:
            strbuild += word + ';'
    if ';' in strbuild: strbuild = strbuild[:-1]
    strbuild += ']'
    return strbuild    

def getdictionary(topK = 10, stop_set = set(), label = 5, maxLen = 5000):
    data_keyword = pd.read_csv(model_path + 'data_keyword.csv')
    data_score = data.copy()
    data_score = pd.merge(data_keyword, data_score[['Id', 'Score']], on = 'Id', how = 'left')
    all_words = []
    for i in range(topK):
        words = get_keywords(data_score, stop_set = stop_set, feature = 'key_word_' + str(i), label = label)
        all_words.extend(words)
    word_num, count, dictionary, reverse_dictionary = build_dataset(all_words, vocabulary_size=min(maxLen, len(all_words)))
    print(count[0:100])
    return dictionary

# test
from collections import Counter
print(Counter(['a', 'a', 'v', 'b', 'b', 'b', 'c', 'd', 'd', 'd', 'b']).most_common(3))

print(senti_snownlp('你好'))

significant_dictionary = read_file_word2dict('../input/significance.txt')
print(significant_dictionary)

import collections
buffer = collections.deque(maxlen=3)
print(buffer)
print(''.join(list(buffer)))
print(len(buffer))

# 停用词 读取
stop_list = read_file_word2set('../input/stop_word.txt')
print(len(stop_list))
print(list(stop_list)[0:100])
# Out:
# [('b', 4), ('d', 3), ('a', 2)]
# 0.5312500000000001
# {'交通': 1, '车': 2, '巴': 3, '索道': 4, '飞机': 5, '住宿': 6, '酒店': 7, '客栈': 8, '旅馆': 9, '民宿': 10, '房间': 11, '宾馆': 12, '床': 13, '窗': 14, '食物': 15, '吃': 16, '味道': 17, '饭': 18, '菜': 19, '干粮': 20, '食品': 21, '零食': 22, '带水': 23, '水果': 24, '饮料': 25, '矿泉水': 26, '餐馆': 27, '饭店': 28, '景': 29, '山水': 30, '风光': 31, '环境': 32, '导游': 33, '司机': 34, '讲解': 35, '解说': 36, '工作人员': 37, '旺季': 38, '节假日': 39, '高峰': 40, '国庆': 41, '春节': 42, '黄金周': 43, '十一': 44, '拥挤': 45, '热闹': 46, '堵': 47, '吵闹': 48, '安静': 49, '轻松': 50, '宁静': 51, '清静': 52, '幽静': 53, '悠闲': 54, '平静': 55, '坑': 56, '骗': 57, '失望': 58, '忽悠': 59, '亲子': 60, '家庭': 61, '儿童': 62, '儿子': 63, '双人': 64, '微信': 65, '厕所': 66, '烧香': 67}
# deque([], maxlen=3)
#
# 0
# 1207
# ['那', '', '不必', '岂止', '陡然', '大概', '虽则', '4', '高低', '（', '不得不', '保险', '比', '如次', '乎', '不过', '5', '几经', '、', '的', '自己', '过于', '分头', '呃', '刚', '个', '从中', '各位', '由于', '暗自', '只要', '白', '俺们', '彻夜', '此中', '_', '不得已', '方', '〈', '不亦乐乎', '到底', '单单', '乘', '反倒', '不料', '得', '其中', '若是', '恰似', ';', '如前所述', '近', '尽', '尽量', '挨次', '从速', '[', '内', '除开', '于是', '你', '凭借', '朝着', '而已', '既然', '8', '何苦', '·', '独', '顷刻之间', '那么', '多年前', '拦腰', '临到', '传闻', '怎么样', '此外', '多亏', '就是说', '老', '大凡', '比如', '挨家挨户', '^', '倒不如说', '鉴于', '大多', '啊', '哼', '粗', '而后', '兮', '极了', '老是', '设使', '２', '不怕', '昂然', '从古至今', '恰恰']

# %%
# 加载数据集
model_path = '../input/'
testFileExist = True

trainFile = model_path + 'train_first.csv'
testFile = model_path + 'predict_first.csv'

train = pd.read_csv(trainFile)
test = pd.read_csv(testFile)

# 数据清洗
# train.drop_duplicates(subset = 'Discuss', keep = 'first', inplace = True)

sns.countplot(x = 'Score',data = train)
plt.show()

print(train['Score'].unique())  # 采取多分类？
print(train.shape, test.shape)


test['Score'] = -1
data = pd.concat([train, test])

# model_path = '../input/subset12/'
# data = pd.read_csv(model_path + 'train_score12.csv')
# testFileExist = False
# Out:
# [5 4 3 2 1]
# (100000, 3) (30000, 2)

# %%
# snownlp 情感分析
if not os.path.exists(model_path + 'senti_snownlp.csv'):
    print('senti_snownlp file not exists...')
    senti_snownlp_df = data[['Id', 'Discuss']].copy()
    senti_snownlp_df['senti_snownlp'] = senti_snownlp_df['Discuss'].apply(lambda x : senti_snownlp(x))
    del senti_snownlp_df['Discuss']
    senti_snownlp_df.to_csv(model_path + 'senti_snownlp.csv', index = False)
    data = pd.merge(data, senti_snownlp_df, on = 'Id', how = 'left')
else:
    print('senti_snownlp file exists...')
    senti_snownlp_df = pd.read_csv(model_path + 'senti_snownlp.csv')
    data = pd.merge(data, senti_snownlp_df, on = 'Id', how = 'left')

    
# 结巴分词
if not os.path.exists(model_path + 'data_jieba.csv'):    
    data_jieba = data[['Id', 'Discuss']].copy()
    data_jieba['words_jieba'] = data_jieba['Discuss'].apply(lambda x : get_jieba_words(x))
    del data_jieba['Discuss']
    data_jieba.to_csv(model_path + 'data_jieba.csv', index = False, encoding = "utf-8")
else:
    print('data_jieba file exists...')
    data_jieba = pd.read_csv(model_path + 'data_jieba.csv')

data_jieba.head()
# Out:
# senti_snownlp file exists...
# data_jieba file exists...
#                                      Id  \
# 0  201e8bf2-77a2-3a98-9fcf-4ce03914e712
# 1  bc578e6d-123e-3833-9a46-d0b4d7dccd0c
# 2  5e03c67a-8103-3b61-9052-82e269cf1c48
# 3  68988e16-af63-34a2-a9aa-8e594d492a3a
# 4  e1813faf-2268-32b3-9bcf-41cb845e6728
#
#                                          words_jieba
# 0  [好大;的;一个;游乐;公园;已经;去;了;2;次;但;感觉;还;没有;玩够;似的;！;会;...
# 1                                            [景色;秀丽]
# 2                              [辉煌;与;屈辱;也;都;成为;了;过去]
# 3  [东方明珠;广播;电视塔;是;上海;的;标志性;文化景观;之一;位于;浦东新区;陆家嘴;塔高...
# 4  [特色;的;建筑;各式;的;小店;好吃;的;小吃;还有;沙滩;和;朋友;和;家人;去;游玩;...

# %%
# 字符串的长度
data['strLen'] = data['Discuss'].apply(lambda x : len(x))
print(data.info())
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 130000 entries, 0 to 129999
# Data columns (total 5 columns):
# Id               130000 non-null object
# Discuss          130000 non-null object
# Score            130000 non-null int64
# senti_snownlp    130000 non-null float64
# strLen           130000 non-null int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 6.0+ MB
# None
#                                      Id  \
# 0  201e8bf2-77a2-3a98-9fcf-4ce03914e712
# 1  f4d51947-eac4-3005-9d3c-2f32d6068a2d
# 2  74aa7ae4-03a4-394c-bee0-5702d3a3082a
# 3  099661c2-4360-3c49-a2fe-8c783764f7db
# 4  97ca672d-e558-3542-ba7b-ee719bba1bab
#
#                                              Discuss  Score  senti_snownlp  \
# 0              好大的一个游乐公园，已经去了2次，但感觉还没有玩够似的！会有第三，第四次的      5       0.521543
# 1                    新中国成立也是在这举行，对我们中国人来说有些重要及深刻的意义！      4       0.996441
# 2                庐山瀑布非常有名，也有非常多个瀑布，只是最好看的非三叠泉莫属，推荐一去      4       0.449366
# 3  个人觉得颐和园是北京最值的一起的地方，不过相比下门票也是最贵的，比起故宫的雄伟与气势磅礴，颐...      5       0.985191
# 4                                             迪斯尼一日游      5       0.972308
#
#    strLen
# 0      37
# 1      31
# 2      35
# 3      61
# 4       6

# %%
def data_word_feature(data_word, feature_word = 'words'):
    # 去除停用词
    stop_list = read_file_word2set('../input/stop_word.txt')
    
    # all words
    dictionary = get_words(data_word, stop_list, feature_word)
    print(len(dictionary))
    word_num, count, dictionary, reverse_dictionary = build_dataset(dictionary, vocabulary_size=50000)
    print(count[:200])

    # negative words
    neg_words = get_neg_words(pd.merge(data_word, data[['Id', 'Score']], on = 'Id', how = 'left'), stop_list, feature_word, 'Score')
    print('neg_words len: ', len(neg_words))
    word_num_neg, count_neg, dictionary_neg, reverse_dictionary_neg = build_dataset(neg_words, vocabulary_size=5000)
    print(count_neg[:100])

    # 群里siginicant word
    significant_dictionary =  read_file_word2dict(model_path + 'significance.txt')
        
    # encoding significant words
    def significant_word(word, dictionary = significant_dictionary):
        sent = word[1:-1]
        words = sent.split(';')
        encoding = 0.0
        arra = []
        for word in words:
            if word in dictionary:
                arra.append(dictionary[word])
        if len(arra) == 0: return 0
        arra = sorted(arra)
        for a in arra:
            encoding = 1.0 * len(dictionary) * encoding + a
        return encoding

    # neg_words 出现的总数
    def neg_words_sum(word, dictionary = dictionary_neg):
        sent = word[1:-1]
        words = sent.split(';')
        cnt = 0
        for word in words:
            if word in dictionary: cnt += 1
        return cnt

    # neg_words 出现的频次
    def neg_words_ratio(word, dictionary = dictionary_neg):
        sent = word[1:-1]
        words = sent.split(';')
        if len(words) == 0: return ''
        cnt = 0
        for word in words:
            if word in dictionary: cnt += 1
        return cnt / len(words)


    def words_to_number(word, dictionary):
        sent = word[1:-1]
        words = sent.split(';')
        data = []
        for word in words:
            if word in dictionary: data.append(dictionary[word])
            else: data.append(0)
        return data

    def words_to_sum(word, dictionary):
        sent = word[1:-1]
        words = sent.split(';')
        data = []
        for word in words:
            if word in dictionary: data.append(dictionary[word])
            else: data.append(0)
        return np.sum(data)

    def words_to_max(word, dictionary):
        sent = word[1:-1]
        words = sent.split(';')
        data = []
        for word in words:
            if word in dictionary.keys(): 
                data.append(dictionary[word])
            else: data.append(0)
        return np.max(data)

    def words_to_std(word, dictionary):
        sent = word[1:-1]
        words = sent.split(';')
        data = []
        for word in words:
            if word in dictionary: data.append(dictionary[word])
            else: data.append(0)
        return np.std(data)

    def words_to_last(word, dictionary):
        sent = word[1:-1]
        words = sent.split(';')
        if len(words) == 0: return ''
        return dictionary[words[0]] if words[0] in dictionary else 0


    def words_to_first(word, dictionary):
        sent = word[1:-1]
        words = sent.split(';')
        if len(words) == 0: return ''
        return dictionary[words[-1]] if words[-1] in dictionary else 0

    def words_len(word):
        sent = word[1:-1]
        words = sent.split(';')
        return len(words)
    
    def hasNtusdPos(word):
        sent = word[1:-1]
        words = sent.split(';')
        if len(words) == 0: return ''
        for word in words:
            if word in ntusd_pos:
                return 1
        return 0
    
    def hasNtusdNum(word, ntusd):
        sent = word[1:-1]
        words = sent.split(';')
        if len(words) == 0: return 0
        cnt = 0
        for word in words:
            if word in ntusd:
                cnt += 1
        return cnt
    
    def hasNtusdNeg(word):
        sent = word[1:-1]
        words = sent.split(';')
        if len(words) == 0: return ''
        for word in words:
            if word in ntusd_neg:
                return 1
        return 0
    
    data_word['word_len_'+ feature_word] = data_word[feature_word].apply(lambda x : words_len(x))
    data_word['word_max_'+ feature_word] = data_word[feature_word].apply(lambda x : words_to_max(x, dictionary))
    data_word['word_std_'+ feature_word] = data_word[feature_word].apply(lambda x : words_to_std(x, dictionary))
    data_word['word_sum_'+ feature_word] = data_word[feature_word].apply(lambda x : words_to_sum(x, dictionary))
    data_word['word_last_'+ feature_word] = data_word[feature_word].apply(lambda x : words_to_last(x, dictionary))
    data_word['word_first_'+ feature_word] = data_word[feature_word].apply(lambda x : words_to_first(x, dictionary))
    data_word['neg_word_sum_'+ feature_word] = data_word[feature_word].apply(lambda x : neg_words_sum(x, dictionary_neg))
    data_word['neg_word_ratio_'+ feature_word] = data_word[feature_word].apply(lambda x : neg_words_ratio(x, dictionary_neg))
    data_word['significant_word_encoding_'+ feature_word] = data_word[feature_word].apply(lambda x : significant_word(x, significant_dictionary))
        
    # ntusd_pos
    data_word['word_ntusd_hasPos'+ feature_word] = data_word[feature_word].apply(lambda x : hasNtusdPos(x))
    data_word['word_ntusd_hasNeg'+ feature_word] = data_word[feature_word].apply(lambda x : hasNtusdNeg(x))
    data_word['word_ntusd_hasPosNum'+ feature_word] = data_word[feature_word].apply(lambda x : hasNtusdNum(x, ntusd_pos))
    data_word['word_ntusd_hasNegNum'+ feature_word] = data_word[feature_word].apply(lambda x : hasNtusdNum(x, ntusd_neg))
    
    # get key word dictionary
    dict_5 = getdictionary(topK = 10, stop_set = stop_list, label = 5, maxLen = 5000)
    data_word['word_max_'+ feature_word + 'score_5'] = data_word[feature_word].apply(lambda x : words_to_max(x, dict_5))
    data_word['word_std_'+ feature_word + 'score_5'] = data_word[feature_word].apply(lambda x : words_to_std(x, dict_5))
    data_word['word_sum_'+ feature_word + 'score_5'] = data_word[feature_word].apply(lambda x : words_to_sum(x, dict_5))
    data_word['word_last_'+ feature_word + 'score_5'] = data_word[feature_word].apply(lambda x : words_to_last(x,dict_5))
    data_word['word_first_'+ feature_word + 'score_5'] = data_word[feature_word].apply(lambda x : words_to_first(x, dict_5))
    
    dict_4 = getdictionary(topK = 10, stop_set = stop_list, label = 4, maxLen = 5000)
    data_word['word_max_'+ feature_word + 'score_4'] = data_word[feature_word].apply(lambda x : words_to_max(x, dict_4))
    data_word['word_std_'+ feature_word + 'score_4'] = data_word[feature_word].apply(lambda x : words_to_std(x, dict_4))
    data_word['word_sum_'+ feature_word + 'score_4'] = data_word[feature_word].apply(lambda x : words_to_sum(x, dict_4))
    data_word['word_last_'+ feature_word + 'score_4'] = data_word[feature_word].apply(lambda x : words_to_last(x,dict_4))
    data_word['word_first_'+ feature_word + 'score_4'] = data_word[feature_word].apply(lambda x : words_to_first(x, dict_4))
    
    dict_3 = getdictionary(topK = 10, stop_set = stop_list, label = 3, maxLen = 5000)
    data_word['word_std_'+ feature_word + 'score_3'] = data_word[feature_word].apply(lambda x : words_to_std(x, dict_3))
    data_word['word_sum_'+ feature_word + 'score_3'] = data_word[feature_word].apply(lambda x : words_to_sum(x, dict_3))
    data_word['word_last_'+ feature_word + 'score_3'] = data_word[feature_word].apply(lambda x : words_to_last(x,dict_3))
    data_word['word_first_'+ feature_word + 'score_3'] = data_word[feature_word].apply(lambda x : words_to_first(x, dict_3))
    
    dict_2 = getdictionary(topK = 10, stop_set = stop_list, label = 2, maxLen = 5000)
    data_word['word_max_'+ feature_word + 'dict_2'] = data_word[feature_word].apply(lambda x : words_to_max(x, dict_2))
    data_word['word_std_'+ feature_word + 'dict_2'] = data_word[feature_word].apply(lambda x : words_to_std(x, dict_2))
    data_word['word_sum_'+ feature_word + 'dict_2'] = data_word[feature_word].apply(lambda x : words_to_sum(x, dict_2))
    data_word['word_last_'+ feature_word + 'dict_2'] = data_word[feature_word].apply(lambda x : words_to_last(x,dict_2))
    data_word['word_first_'+ feature_word + 'dict_2'] = data_word[feature_word].apply(lambda x : words_to_first(x, dict_2))
    
    dict_1 = getdictionary(topK = 10, stop_set = stop_list, label = 1, maxLen = 5000)
    data_word['word_max_'+ feature_word + 'dict_1'] = data_word[feature_word].apply(lambda x : words_to_max(x, dict_1))
    data_word['word_std_'+ feature_word + 'dict_1'] = data_word[feature_word].apply(lambda x : words_to_std(x, dict_1))
    data_word['word_sum_'+ feature_word + 'dict_1'] = data_word[feature_word].apply(lambda x : words_to_sum(x, dict_1))
    data_word['word_last_'+ feature_word + 'dict_1'] = data_word[feature_word].apply(lambda x : words_to_last(x,dict_1))
    data_word['word_first_'+ feature_word + 'dict_1'] = data_word[feature_word].apply(lambda x : words_to_first(x, dict_1))
    
    return data_word
# 加载 词典集
ntusd_pos = read_file_word2set(model_path + 'NTUSD_positive_simplified.txt', encoding = 'utf-8')
ntusd_neg = read_file_word2set(model_path + 'NTUSD_negative_simplified.txt', encoding = 'utf-8')

# hancks 分词
train_word = pd.read_csv(model_path + 'train_word.csv')
if testFileExist: 
    test_word = pd.read_csv(model_path + 'predict_word.csv')
    data_word = pd.concat([train_word, test_word])
else:
    data_word = train_word
    
stop_list = read_file_word2set(model_path + 'stop_word.txt')
# data_word['words'] = data_word['words'].apply(lambda x : clean_str(x, stop_list = stop_list))

# 群里siginicant word
significant_dictionary =  read_file_word2dict(model_path + 'significance.txt')
def contain(word, key):
    return 1 if key in word else 0

for _, key in enumerate(significant_dictionary.keys()):
    data_word['significant_key_{}'.format(_)] = data_word['words'].apply(lambda x : contain(x, key))

data_word = data_word_feature(data_word, feature_word = 'words')
data = pd.merge(data, data_word.drop(['words'], axis = 1), on = 'Id', how = 'left')

# jieba 分词
data_jieba = data_word_feature(data_jieba, feature_word = 'words_jieba')
data = pd.merge(data, data_jieba.drop(['words_jieba'], axis = 1), on = 'Id', how = 'left')
# Out:
# 2005197
# {'UNK': 0, '人': 1, '不错': 2, '<br': 3, '一个': 4, '地方': 5, '好': 6, '景区': 7, '值得': 8, '景点': 9, '感觉': 10, '美': 11, '风景': 12, '比较': 13, '>rn': 14, '走': 15, '里面': 16, '景色': 17, '门票': 18, '次': 19, '玩': 20, '真的': 21, '天': 22, '看到': 23, '很好': 24, '元': 25, '时间': 26, '点': 27, '年': 28, '特别': 29, '说': 30, '北京': 31, '方便': 32, '最': 33, '看看': 34, '两': 35, '西湖': 36, '坐': 37, '小时': 38, '建筑': 39, '喜欢': 40, '小': 41, '太': 42, '下': 43, '一定': 44, '>n': 45, '里': 46, '历史': 47, '中国': 48, '觉得': 49, '后': 50, '中': 51, '建议': 52, '游客': 53, '适合': 54, '票': 55, '挺': 56, '旅游': 57, '晚上': 58, '第一': 59, '特色': 60, '位于': 61, '再': 62, '有点': 63, '推荐': 64, '很大': 65, '山': 66, '黄山': 67, '游': 68, '一下': 69, '吃': 70, '座': 71, '现在': 72, '公园': 73, '太多': 74, '游玩': 75, '米': 76, '需要': 77, '爬': 78, '杭州': 79, '想': 80, '导游': 81, '买': 82, '排队': 83, '环境': 84, '已经': 85, '壮观': 86, '索道': 87, '天气': 88, '文化': 89, '贵': 90, '知道': 91, '高': 92, '条': 93, '漂亮': 94, '山上': 95, '东西': 96, '水': 97, '一些': 98, '时': 99, '月': 100, '选择': 101, '世界': 102, '爬山': 103, '主要': 104, '好玩': 105, '逛': 106, '只': 107, '最好': 108, '累': 109, '一起': 110, '直接': 111, '游览': 112, '10': 113, '开心': 114, '做': 115, '泰山': 116, '拍照': 117, '应该': 118, '瀑布': 119, '拍': 120, '美丽': 121, '好多': 122, '孩子': 123, '整个': 124, '少': 125, '体验': 126, '故宫': 127, '朋友': 128, '一直': 129, '没什么': 130, '感受': 131, '震撼': 132, '山顶': 133, '种': 134, '缆车': 135, '美景': 136, '免费': 137, '日出': 138, '确实': 139, '第二': 140, '上山': 141, '表演': 142, '真是': 143, '参观': 144, '车': 145, '讲解': 146, '很漂亮': 147, '附近': 148, '一路': 149, '一点': 150, '号': 151, '赞': 152, '住': 153, '好看': 154, '只能': 155, '前': 156, '价格': 157, '门口': 158, '古城': 159, '路': 160, '挺好': 161, '之后': 162, '公里': 163, '下山': 164, '过去': 165, '好好': 166, '取': 167, '古镇': 168, '站': 169, '下来': 170, '最大': 171, '进入': 172, '分钟': 173, '长城': 174, '便宜': 175, '交通': 176, '空气': 177, '找': 178, '风光': 179, '服务': 180, '夏天': 181, '不用': 182, '可惜': 183, '项目': 184, '总体': 185, '进': 186, '点评': 187, '当时': 188, '20': 189, '话': 190, '30': 191, '花': 192, '下午': 193, '著名': 194, '左右': 195, '国家': 196, '来到': 197, '广场': 198, '日': 199, '到达': 200, '超级': 201, '听': 202, '性价比': 203, '之前': 204, '长': 205, '三清山': 206, '买票': 207, '照片': 208, '很棒': 209, '季': 210, '早上': 211, '下次': 212, '以后': 213, '最后': 214, '处': 215, '发现': 216, '印象': 217, '网上': 218, '有奖': 219, '区': 220, '当地': 221, '自然': 222, '冬天': 223, '湖': 224, '栈道': 225, '十': 226, '旅行': 227, '景观': 228, '坑': 229, '步行': 230, '片': 231, '棒': 232, '开': 233, '来说': 234, '味道': 235, '上面': 236, '这次': 237, '气息': 238, '还行': 239, '九寨沟': 240, '园林': 241, '12': 242, '却': 243, '先': 244, '景': 245, '设施': 246, '古代': 247, '晚': 248, '中的': 249, '机会': 250, '好像': 251, '出游': 252, '卖': 253, '夜景': 254, '值得一看': 255, '尤其': 256, '体检': 257, '圈': 258, '十分': 259, '兵马俑': 260, '遗憾': 261, '欣赏': 262, '旁边': 263, '完全': 264, '天安门': 265, '博物馆': 266, '身份证': 267, '寺庙': 268, '实在': 269, '动物': 270, '张': 271, '&quot': 272, '般': 273, '艺术': 274, '刺激': 275, '西': 276, '休闲': 277, '块': 278, '开放': 279, '想象': 280, '不好': 281, '商业化': 282, '风景区': 283, '票价': 284, '约': 285, '级': 286, '上海': 287, '记得': 288, '面积': 289, '江南': 290, '路上': 291, '东': 292, '了解': 293, '算是': 294, '还好': 295, '栅': 296, '看见': 297, '周末': 298, '入': 299, '成': 300, '走到': 301, '张家界': 302, '不到': 303, '段': 304, '以前': 305, '提前': 306, '外面': 307, '季节': 308, '收费': 309, '唯一': 310, '乘坐': 311, '桥': 312, '层': 313, '家': 314, '慢慢': 315, '开发': 316, '小吃': 317, '请': 318, '住宿': 319, '舒服': 320, '生活': 321, '真心': 322, '下雨': 323, '位': 324, '带着': 325, '好吃': 326, '干净': 327, '公交': 328, '园': 329, '酒店': 330, '>rn<br': 331, '分': 332, '城市': 333, '亲子游': 334, '每个': 335, '北京市': 336, '下车': 337, '这种': 338, '逛逛': 339, '超': 340, '故事': 341, '海拔': 342, '全': 343, '还要': 344, '一日游': 345, '路过': 346, '体力': 347, '位置': 348, '看着': 349, '介绍': 350, '云海': 351, '迪士尼': 352, '远': 353, '15': 354, '天下': 355, '街': 356, '真': 357, '最美': 358, '都会': 359, '希望': 360, '白天': 361, '西塘': 362, '买了': 363, '大自然': 364, '过来': 365, '美的': 366, '租': 367, '都江堰': 368, '外': 369, '100': 370, '节假日': 371, '字': 372, '商业': 373, '雨': 374, '50': 375, '路线': 376, '失望': 377, '整体': 378, '周边': 379 ...
# [['UNK', 45072], ('人', 19245), ('不错', 17065), ('<br', 13191), ('一个', 12210), ('地方', 11896), ('好', 11706), ('景区', 11426), ('值得', 9536), ('景点', 8664), ('感觉', 8189), ('美', 7932), ('风景', 7747), ('比较', 6853), ('>rn', 6659), ('走', 6570), ('里面', 6434), ('景色', 6375), ('门票', 6349), ('次', 6283), ('玩', 6208), ('真的', 6034), ('天', 5995), ('看到', 5820), ('很好', 5529), ('元', 5450), ('时间', 5164), ('点', 4784), ('年', 4680), ('特别', 4625), ('说', 4578), ('北京', 4559), ('方便', 4516), ('最', 4498), ('看看', 4476), ('两', 4451), ('西湖', 4349), ('坐', 4266), ('小时', 4134), ('建筑', 4108), ('喜欢', 4096), ('小', 3969), ('太', 3909), ('下', 3857), ('一定', 3758), ('>n', 3721), ('里', 3696), ('历史', 3689), ('中国', 3671), ('觉得', 3657), ('后', 3622), ('中', 3508), ('建议', 3482), ('游客', 3395), ('适合', 3391), ('票', 3310), ('挺', 3268), ('旅游', 3253), ('晚上', 3231), ('第一', 3218), ('特色', 3208), ('位于', 3132), ('再', 3126), ('有点', 3078), ('推荐', 3073), ('很大', 3072), ('山', 2989), ('黄山', 2960), ('游', 2928), ('一下', 2926), ('吃', 2895), ('座', 2886), ('现在', 2873), ('公园', 2820), ('太多', 2794), ('游玩', 2778), ('米', 2713), ('需要', 2630), ('爬', 2572), ('杭州', 2532), ('想', 2531), ('导游', 2492), ('买', 2483), ('排队', 2465), ('环境', 2448), ('已经', 2444), ('壮观', 2374), ('索道', 2367), ('天气', 2357), ('文化', 2293), ('贵', 2220), ('知道', 2205), ('高', 2201), ('条', 2199), ('漂亮', 2179), ('山上', 2173), ('东西', 2170), ('水', 2150), ('一些', 2137), ('时', 2136), ('月', 2118), ('选择', 2110), ('世界', 2087), ('爬山', 2079), ('主要', 2075), ('好玩', 2064), ('逛', 2043), ('只', 2036), ('最好', 2020), ('累', 2015), ('一起', 2006), ('直接', 1982), ('游览', 1977), ('10', 1971), ('开心', 1964), ('做', 1914), ('泰山', 1906), ('拍照', 1891), ('应该', 1850), ('瀑布', 1849), ('拍', 1842), ('美丽', 1826), ('好多', 1825), ('孩子', 1803), ('整个', 1802), ('少', 1774), ('体验', 1770), ('故宫', 1762), ('朋友', 1761), ('一直', 1757), ('没什么', 1755), ('感受', 1732), ('震撼', 1703), ('山顶', 1691), ('种', 1674), ('缆车', 1669), ('美景', 1662), ('免费', 1660), ('日出', 1641), ('确实', 1627), ('第二', 1620), ('上山', 1614), ('表演', 1598), ('真是', 1591), ('参观', 1586), ('车', 1573), ('讲解', 1550), ('很漂亮', 1550), ('附近', 1541), ('一路', 1534), ('一点', 1527), ('号', 1524), ('赞', 1516), ('住', 1516), ('好看', 1503), ('只能', 1491), ('前', 1491), ('价格', 1484), ('门口', 1482), ('古城', 1475), ('路', 1471), ('挺好', 1470), ('之后', 1465), ('公里', 1449), ('下山', 1434), ('过去', 1427), ('好好', 1422), ('取', 1415), ('古镇', 1414), ('站', 1412), ('下来', 1402), ('最大', 1399), ('进入', 1396), ('分钟', 1395), ('长城', 1389), ('便宜', 1380), ('交通', 1378), ('空气', 1367), ('找', 1363), ('风光', 1361), ('服务', 1355), ('夏天', 1355), ('不用', 1353), ('可惜', 1347), ('项目', 1344), ('总体', 1342), ('进', 1342), ('点评', 1342), ('当时', 1332), ('20', 1327), ('话', 1317), ('30', 1315), ('花', 1299), ('下午', 1298), ('著名', 1294), ('左右', 1289), ('国家', 1278), ('来到', 1268), ('广场', 1262), ('日', 1261)]
# neg_words len:  11809
# [['UNK', 0], ('一个', 149), ('景区', 136), ('说', 133), ('人', 127), ('门票', 103), ('景点', 90), ('地方', 75), ('<br', 64), ('元', 60), ('里面', 57), ('小时', 56), ('两', 54), ('票', 53), ('买', 52), ('差', 51), ('坑', 46), ('点', 44), ('真的', 44), ('走', 44), ('太', 43), ('好', 43), ('感觉', 42), ('失望', 42), ('值得', 41), ('次', 40), ('坐', 39), ('知道', 39), ('没什么', 37), ('想', 37), ('后', 36), ('>n', 36), ('导游', 35), ('排队', 35), ('贵', 34), ('玩', 33), ('已经', 32), ('游客', 32), ('收费', 31), ('全', 31), ('最', 30), ('旅游', 30), ('工作人员', 29), ('再', 29), ('车', 29), ('差评', 29), ('张', 28), ('垃圾', 28), ('钱', 27), ('天', 27), ('管理', 27), ('一点', 26), ('东西', 26), ('根本', 26), ('收', 26), ('比较', 25), ('司机', 25), ('缆车', 25), ('建议', 24), ('看到', 24), ('花', 24), ('进', 24), ('只能', 24), ('问', 24), ('呵呵', 24), ('风景', 23), ('10', 23), ('完全', 23), ('买票', 23), ('之后', 22), ('小', 22), ('不错', 21), ('服务', 20), ('不值', 20), ('吃', 20), ('第二', 20), ('下', 20), ('网上', 20), ('特别', 20), ('这种', 20), ('真是', 20), ('一下', 20), ('还要', 19), ('块', 19), ('买了', 19), ('坑人', 19), ('觉得', 19), ('时间', 18), ('直接', 18), ('卖', 18), ('开', 18), ('里', 18), ('丽江', 18), ('古城', 18), ('20', 17), ('条', 17), ('做', 17), ('号', 17), ('以后', 17), ('真', 17)]
# 好 6
# 一个 4
# 游乐 921
# 公园 73
# 已经 85
# 次 19
# 感觉 10
# 玩 20
# 够 734
# 次 19
# 921
# 新中国 5547
# 成立 3638
# 举行 1776
# 中国人 2767
# 来说 234
# 重要 433
# 深刻 767
# 意义 536
# 5547
# 庐山 720
# 瀑布 119
# 有名 382
# 瀑布 119
# 最 33
# 好看 154
# 非 1161
# 三叠泉 2706
# 属 1267
# 推荐 64
# 2706
# 觉得 49
# 颐和园 421
# 北京 31
# 最 33
# 值 527
# 一起 110
# 地方 5
# 相比 909
# 下 43
# 门票 18
# 最贵 7810
# 故宫 127
# 雄伟 548
# 气势磅礴 1695
# 颐和园 421
# 宁静 992
# 波光粼粼 4891
# 美 11
# 7810
# 迪斯尼 1314
# 一日游 345
# 1314
# 方便 32
# 32
# 水 97
# 看山 963
# 感受 131
# 古人 597
# 智慧 563
# 结晶 2892
# 秋景 10634
# 美丽 121
# 画 629
# 红黄 17055
# 绿 1139
# 相间 6263
# 身体状况 27272
# 佳 2546
# 人 1
# 来说 234
# 走 15
# 平路 8239
# 接受 1825
# 27272
# 赞 152
# 152
# 唯一 310
# 糟 12966
# 点 27
# 12966
# 周未 27273
# 周边 379
# 游 68
# 27273
# 景点 9
# 服务 180
# 不错 2
# 排队 83
# 太长 2169
# 好玩 105
# 项目 184
# 人 1
# 晚上 58
# 烟火 6804
# 一定 44
# 真的 21
# 不错 2
# 做好 1166
# 攻 18353
# 18353
# 绍兴 812
# 护城河 4197
# 夜游 1859
# 4197
# 感觉 10
# 不错 2
# 一日游 345
# 错 1379
# 选择 101
# 1379
# 有趣 636
# hai 31959
# 31959
# 荡气回肠 15070
# 10 113
# 年 28
# 留下来 4803
# 照片 208
# 必然 5740
# 再 62
# <br 3
# >n 45
# 15070
# 景色 17
# 超级 201
# 棒 232
# 美丽 121
# 故事 341
# 乘船 2121
# 游览 112
# 沿湖 5025
# 浏览 2059
# 累 109
# 乘坐 311
# 观光车 714
# 关键 1760
# 门票 18
# 5025
# 南锣鼓巷 693
# 北京市中心 27274
# 条 93
# 胡同 480
# 地理位置 1777
# 靠近 1657
# 什刹海 1078
# 成为 419
# 好去处 399
# 特别 29
# 外国 3262
# 游人 402
# 特别 29
# 许多 397
# 中国 48
# 符号 12967
# 文化 89
# 商品 3448
# 买 82
# 餐饮 2015
# 商家 3030
# 具 1533
# 鲜明 4668
# 特点 922
# 使 903
# 整个 124
# 地区 980
# 种 134
# 中西合璧 7459
# 感觉 10
# 每次 668
# 世界杯 31960
# 期间 817
# 气氛 1428
# 无比 1589
# 热烈 15996
# 来到 197
# 一定 44
# 感染 14276
# 之前 204
# 银两 38830
# 准备 561
# 充足 2517
# 38830
# 个人感觉 1188
# 卖 253
# 小商品 5644
# 地方 5
# 便宜 175
# 晚上 58
# 夜景 254
# 挺 56
# 好看 154
# 5644
# 性价比 203
# 超高 3999
# 3999
# 挺 56
# 普通 797
# 楼下 5362
# 拍 120
# 几张 1899
# 图片 1149
# 反正 865
# 进不去 3855
# 5362
# 太大 450
# 里面 16
# 走 15
# 好长时间 9907
# 不到 303
# 分之一 3894
# 周围 405
# 交通 176
# 方便 32
# 值得 8
# 看一看 1120
# 9907
# 迪士尼 352
# 352
# 亲子游 334
# 334
# 苏州 651
# 总是 1090
# 欣赏 262
# 一下 69
# 古典 2000
# 园林 241
# 可惜 183
# 园林 241
# 太 42
# 感冒 4804
# 逛逛 339
# 玩玩 983
# 不错 2
# 4804
# 不到长城非好汉 1079
# 爬过 4092
# 华山 1182
# 来说 234
# 长城 174
# 太 42
# 简单 1068
# 值得 8
# 4092
# 值得 8
# 地方 5
# 8
# 第一 59
# 次 19
# 景点 9
# 59
# 好歹 11040
# 长城 174
# 11040
# 早上 211
# 一大早 2316
# 起床 2373
# 升国旗 3064
# 庄严 834
# 整齐 3795
# 一个 4
# 节目 1333
# 人 1
# 转 430
# 不开 3528
# 眼睛 2673
# 特别 29
# 老辈 38831
# 人 1
# 听说 505
# 天天 4152
# 都会 359
# 跟着 725
# 唱国歌 38832
# 画面 2159
# 感动 2940
# 38832
# 登顶 1032
# 俯瞰 630
# 故宫 127
# 绝佳 1900
# 之处 1287
# 崇祯帝 38833
# 自缢 13574
# 38833
# 西湖 36
# 美景 136
# 真的 21
# 太美 477
# 无法形容 5275
# 5275
# 龙王洞 38834
# 美 11
# 好看 154
# 38834
# 风景 12
# 可言 7285
# 座 71
# 寺庙 268
# 有点 63
# 年代 1288
# 7285
# 花卉 3895
# 值得 8
# 看看 34
# 温带 24177
# 热带 3393
# 寒带 31961
# 植物 702
# 觉得 49
# 老年人 2389
# 特别 29
# 爱 471
# 呵呵 607
# 31961
# 玩 20
# 不错 2
# 票 55
# 旁边 263
# 有人 466
# 说 30
# 125一 38835
# 人 1
# 现在 72
# 95 5448
# 半价 1715
# 优惠 594
# 知道 91
# 希望 360
# 下次 212
# 点 27
# 行程 439
# 不错 2
# 38835
# 还行 239
# 239
# 一个 4
# 公园 73
# 每个 335
# 季节 308
# 色彩 1357
# 松鼠 2455
# 岛 545
# 鹿苑 18354
# 天鹅湖 8958
# 花卉园 21790
# 一个 4
# 拍 120
# 婚纱 4565
# 好去处 399
# 三五 10279
# 朋友 128
# 情侣 1414
# 租 367
# 自行车 756
# 环游 8473
# 一个 4
# 美妙 2984
# 选择 101
# 21790
# 天街 4735
# 景色 17
# 十分 259
# 美 11
# 尝尝 3603
# 美食 707
# 4735
# 租 367
# 小池 19886
# 家人 646
# 享用 13575
# 19886
# 夏季 1167
# 端午节 5363
# 假期 900
# 上午 777
# 人 1
# 太阳 590
# 毒 14277
# 依然 935
# 转 430
# 开心 114
# 一定 44
# 看看 34
# 14277
# 划算 925
# 925
# 好 6
# 环境 84
# 不错 2
# 人 1
# 性价比 203
# 高 92
# 温泉水 8240
# 不错 2
# 喝 915
# 休闲 277
# 休闲 277
# 休闲 277
# 休闲 277
# 8240
# 挺好玩 1133
# 时间 26
# 紧张 2402
# 2402
# 烟袋斜街 3707
# 走 15
# 过去 165
# 看到 23
# 桥 312
# 样子 631
# 普通 797
# 北京 31
# 文化 89
# 代表 806
# 3707
# 取 167
# 票 55
# 窗口 1289
# 十分 259
# 方便 32
# 上山 141
# 云谷 4624
# 索道排队 7460
# 排 409
# 两 35
# 小时 38
# 下山 164
# 玉屏 4457
# 索道 87
# 又是 1367
# 两 35
# 小时 38
# 当天 624
# 最 33
# 美丽 121
# 风景 12
# 人海 8044
# 8044
# 怎么说 1961
# 仙山 2329
# 喜爱 3796
# 已经 85
# 超过 2016
# 故宫 127
# 3796
# 十里 1740
# 长安 2360
# 街 356
# 中国 48
# 标志性 618
# 地段 4410
# 4410
# 留有 5934
# 历史 47
# 痕迹 1682
# 景色 17
# 不错 2
# 5934
# 寺前 15071
# 香火 973
# 缭绕 866
# 信徒 2893
# 虔诚 1264
# 叩拜 10635
# 信仰 2028
# 件 876
# 幸福 2330
# 事儿 6051
# 15071
# 条 93
# 条 93
# 小路 1504
# 洋溢着 18355
# 文艺 741
# 气息 238
# 真的 21
# 好 6
# 美 11
# 18355
# 滑雪场 3639
# 中 51
# 西式 9908
# 餐厅 1063
# 咖啡厅 8959
# 足疗 31962
# 室 7811
# 雪具 24178
# 专卖店 31963
# 超市 6155
# 服务设施 4411
# 随时 3421
# 滑雪者 38836
# 提供 910
# 一流 2674
# 服务 180
# 优越 5741
# 地理位置 1777
# 金色 3175
# 夜场 2340
# 滑雪 1199
# 使 903
# 自驾车 4198
# 40 391
# 分钟 173
# 后 50
# 转换 15997
# 角色 12968
# 游走 4458
# 白天 361
# 夜晚 715
# 浪漫 1689
# 交替 12969
# 中 51
# 38836
# 完美 639
# 开心 114
# 639
# 座 71
# 还算 649
# 不错 2
# 寺庙 268
# 风景 12
# 不错 2
# 649
# 皇帝 406
# 澡堂 27275
# 一部分 1338
# 建筑 39
# 正在 1306
# 施工 3896
# 旁边 263
# 山 66
# 晚上 58
# 演出 456
# <br 3
# 地方 5
# 好 6
# 民国时期 5742
# 好像 251
# 27275
# 西湖 36
# 不用 182
# 说 30
# 中国 48
# 境内 1299
# 收 778
# 五星级 4964
# 免 2475
# 门票 18
# 景点 9
# 政府 3529
# 很给力 1975
# 手段 8474
# 吸引 595
# 游客 53
# 带动 11041
# 诸多 5548
# 副业 31964
# 建议 52
# 官员 7461
# 参考 2877
# 周边 379
# 景点 9
# 太多 74
# 后面 475
# 单独 1213
# 一个 4
# 讲解 146
# 只 107
# 做 115
# 笼统 38837
# 概述 27276
# 建议 52
# 先 244
# 每人 1307
# 租 367
# 辆 1476
# 自行车 756
# 环湖 1877
# 骑行 1514
# 熟悉 1847
# 感觉 10
# 一下 69
# 20 189
# 元 25
# 辆 1476
# 议价 18356
# 预计 7812
# 1.5 2456
# 小时 38
# 花 192
# 百 612
# 块 278
# 条 93
# 小船 1962
# 荡起 4093
# 双桨 4348
# 感受 131
# 湖面 577
# 景色 17
# 建议 52
# 春夏 5549
# 之际 6969
# 最佳 694
# 杭州 79
# 吃 70
# 不用 182
# 说 30
# 特色 60
# 诸如 11476
# 知 3752
# 味 1463
# 观 770
# 新 553
# 白鹿 15998
# 推荐 64
# 议价 18356
# 性价比 203
# 较高 3176
# 小吃 317
# 古色古香 1268
# 西湖 36
# 旁边 263
# 龙翔桥 21791
# 地铁 429
# B 2918
# 出口 1064
# 斜对面 11954
# 音乐 696
# 喷泉 564
# 人均 5026
# 30 191
# 50 375
# 元 25
# 十 226
# 种 134
# 浙西 6805
# 衢州 600
# 古城 159
# 特色小吃 2675
# 38837
# 强烈推荐 1118
# 世界 102
# 八大 1640
# 奇迹 1075
# 1640
# 乌 6052
# 将军庙 21792
# 乌镇 428
# 市 869
# 河西 11955
# 岸 3208
# 剧场 3094
# 北面 3065
# 原来 538
# 座 71
# 古庙 17056
# 叫做 2676
# 乌 6052
# 将军庙 21792
# 庙 1380
# 内有 1761
# 棵 2113
# 古老 601
# 银杏树 5193
# 庙 1380
# 已不 9260
# 存 2985
# 棵 2113
# 银杏 2529
# 巍然矗立 38838
# 38838
# 完美 639
# 出行 420
# 639
# 求子 12437
# 之处 1287
# 景色 17
# 十分 259
# 优美 507
# 特色 60
# 12437
# 今年 1231
# 正巧 10636
# 赶上 483
# 狮子山 9909
# 台风 3263
# 连续 4892
# 封 4244
# 最后 214
# 离开 1483
# 那天 451
# 终于 572
# 北坡 2317
# 幸运 1515
# 亲眼目睹 11956
# 天池 498
# 真容 9261
# 这么久 8960
# 值得 8
# 11956
# 绝景 4736
# 感受 131
# 短 1741
# 4736
# 公交车 392
# 老板 802
# 开车 487
# 载 3797
# 直接 111
# 客栈 824
# 安顿 14278
# 好 6
# 行李 1976
# 后 50
# 迫不及待 9910
# 河边 2677
# 烟雨 1046
# 长廊 840
# 古老 601
# 悠长 8241
# 巷子 1516
# 小桥流水 1017
# 如同 2650
# 画 629
# 中 51
# 临河 7462
# 饭店 1604
# 吃 70
# 午餐 3298
# 后 50
# 客栈 824
# 休息 385
# 傍晚 952
# 时分 5027
# 再次 1563
# 走过 798
# 古巷 7813
# 感受 131
# 沧桑 2271
# 暮色 15999
# 下 43
# 西塘 362
# 人 1
# 又是 1367
# 另一番 10280
# 宁静 992
# 感觉 10
# 古镇 168
# 来说 234
# 过多 3449
# 游客 53
# 喧嚣 2090
# 打扰 8475
# 宁静 992
# 外来 8242
# 游客 53
# 像是 1037
# 外来 8242
# 入侵者 38839
# 38839
# 一价 21793
# 全包 18357
# 21793
# 玩玩 983
# 983
# 水 97
# 清凉 2170
# 沙滩 627
# 碎 11042
# 珊瑚 13576
# 13576
# 方便 32
# 出行 420
# 420
# 天安门城楼 2651
# 壮观 86
# 广场 198
# 特别 29
# 2651
# 三寸金莲 9911
# 鞋 3530
# 以前 305
# 电视 1464
# 根本 602
# 实际 1796
# 看到 23
# 好 6
# 小 41
# 9911
# 孩子 123
# 觉得 49
# 摩天轮 3640
# 有意思 410
# 3640
# 最近 1208
# 西安 484
# 兴起 11043
# 主体 1901
# 公园 73
# 晚上 58
# 水幕 4293
# 电影 549
# 不错 2
# 11043
# 鸣沙山 1257
# 月牙泉 1177
# 景区 7
# 真正 481
# 的沙漠 6806
# 奇观 1258
# 现在 72
# 评为 3139
# 国家 196
# AAAAA 1521
# 级 286
# 旅游 57
# 景区 7
# 6806
# 八字桥 7814
# 景区 7
# 书圣 9576
# 故里 1429
# 适合 54
# 慢慢 315
# 逛 106
# 9576
# 景点 9
# 成熟 2029
# 游客 53
# 众多 751
# 商店 2518
# 高度 2017
# 同质化 12438
# 12438
# 走过 798
# 柳浪闻莺 4199
# 看到 23
# 钱王祠 9577
# 后人 2833
# 纪念 830
# 吴越 7815
# 国 2919
# 王钱 38840
# 鏐 27277
# liu 31965
# 功绩 10637
# 建造 990
# 有兴趣 2417
# 看看 34
# 38840
# 可惜 183
# 那天 451
# 下雨 323
# 完爆 24179
# 天池 498
# 下次 212
# 再 62
# 24179
# 爱 471
# 北京 31
# 天安门 265
# 天安门 265
# 太阳升 11044
# 历史 47
# 意义 536
# 重大 4349
# 早上 211
# 等待 1797
# 升旗仪式 4153
# 接受 1825
# 爱国 4566
# 教育 904
# 每一次 6807
# 心潮澎湃 12439
# ~<br 1283
# >n 45
# 12439
# 江南百床馆 15072
# 中国 48
# 一家 394
# 专门 905
# 收藏 2134
# 展出 2812
# 江南古 14279
# 床 2547
# 博物馆 266
# 百 612
# 床馆 27278
# 并不 902
# 穷究 38841
# 收容 38842
# 下 43
# 数量 2745
# 细细品味 4094
# 张 271
# 张 271
# 精美 1210
# 床上 12970
# 所加 38843
# 载 3797
# 丰富 476
# 历史 47
# 生活 321
# 内涵 2018
# 门票 18
# 包含 1098
# 门票 18
# 开发 316
# 时间 26
# 00 716
# 17 1584
# 30 191
# 38843
# 真心 322
# 不错 2
# 值得 8
# 游玩 75
# 天 22
# 时间 26
# 太紧张 21794
# 建议 52
# 游玩 75
# 天 22
# 21794
# 大红岩 19887
# 很大 65
# 绕着 2920
# 山 66
# 走 15
# 圈 258
# 很累 524
# 19887
# 广州市 7630
# 唯一一 3946
# 座 71
# 山 66
# 开发 316
# 成熟 2029
# 景区 7
# 绿化 1522
# 覆盖面积 24180
# 达到 2205
# 92 15073
# 一个 4
# 景区 7
# 五块钱 6970
# 够 734
# 良心 4567
# 风景 12
# 来说 234
# 确实 139
# 点 27
# 环境 84
# 很好 24
# 空气 177
# 很好 24
# 24180
# 雁塔 6508
# 不算 469
# 西安 484
# 大雁塔 995
# 西安 484
# 标志性 618
# 建筑 39
# 玄奘 5550
# 保存 414
# 天竺 9262
# 丝绸之路 6971
# 带回 8476
# 长安 2360
# 经卷 16000
# 佛像 838
# 主持 5364
# 修建 611
# 雁塔 6508
# 来到 197
# 大雁塔 995
# 游客 53
# 仔细观察 18358
# 看到 23
# 大雁塔 995
# 倾斜 7816
# 登塔 4095
# 卖 253
# 门票 18
# 登上 677
# 塔顶 3450
# 西安城 19888
# 近乎 18359
# 一览无余 4568
# 实则 14280
# 神清气爽 6402
# 19888
# 景色 17
# 优美 507
# 宜人 2103
# 性价比 203
# 一如既往 5111
# 好 6
# 5111
# 家庭 637
# 一起 110
# 637
# 商业化 282
# 严重 889
# 餐饮 2015
# 已经 85
# 没什么 130
# 特色 60
# 2015
# 小朋友 443
# 玩 20
# 不逊于 18360
# 广州 1162
# 长 205
# 隆 1590
# 野生动物园 1769
# 18360
# 三清山 206
# 一路 149
# 风景 12
# 美不胜收 783
# 值得 8
# 故地重游 6053
# 6053
# 好 6
# 6
# 家长 4412
# 代表 806
# 巴西 31966
# 今生 15074
# 今世 31967
# 宣布 11477
# 31967
# 一个 4
# 充满 1085
# 小资 2746
# 情调 2747
# 地方 5
# 什刹海 1078
# 胡同 480
# 建议 52
# 早上 211
# 早上 211
# 太早 3531
# 话 190
# 地方 5
# 开门 1578
# 建议 52
# 下午 193
# 晚上 58
# 感受 131
# 那种 417
# 小资 2746
# 情调 2747
# 恭王府 955
# 什刹海 1078
# 临近 4000
# 上午 777
# 先 244
# 早点 1080
# 恭王府 955
# 下午 193
# 再 62
# 什刹海 1078
# 烟袋斜街 3707
# 4000
# 不错 2
# 城市 333
# 值得 8
# 333
# 鸟巢 596
# 开车 487
# 30 191
# 分钟 173
# 鸟巢 596
# 外面 307
# 好看 154
# 里面 16
# 596
# 感觉 10
# 好极了 6972
# 6972
# 漂流 888
# 不错 2
# 周边 379
# 农家院 4096
# 好不 5112
# 惬意 530
# 游泳 2361
# 5112
# 798 1033
# 真的 21
# 宣传 2196
# 差距 4459
# 好 6
# 艺术 274
# 气息 238
# 一点 150
# 浓厚 1191
# 厂区 5365
# 部分 503
# 蛮有意思 5551
# 5551
# 次 19
# 看到 23
# 醉 1612
# 美的 366
# 红叶 1072
# 1612
# 灯会 5645
# 觉得 49
# 灯会 5645
# 破坏 1666
# 原本 1887
# 美感 3358
# 机会 250
# 想 80
# 看看 34
# 通常 4097
# 情况下 3031
# 大唐芙蓉园 4200
# 5645
# 不错 2
# 水乡 1211
# 园林 241
# 中西合璧 7459
# 很漂亮 147
# 7459
# 小吃 317
# 糖葫芦 9578
# 好吃 326
# 春节 929
# 期间 817
# 人 1
# 太多 74
# 太多 74
# 9578
# 环境 84
# 很好 24
# 植被 1094
# 很好 24
# 森林 787
# 氧吧 949
# 慢跑 19889
# 散步 731
# 不错 2
# 19889
# 前门 1585
# 位于 61
# 北京城 1963
# 南北 1134
# 中轴线 1150
# 天安门 265
# 广场 198
# 南缘 12440
# 前门大街 1985
# 北端 5194
# 始建于 752
# 明 831
# 永乐 3032
# 十七 15075
# 年 28
# 原名 2921
# 丽 8706
# 正门 1495
# 后 50
# 改称 4737
# 正阳门 3798
# 因其 3670
# 位于 61
# 紫禁城 1195
# 正前方 14281
# 前门 1585
# 称 457
# 正阳门 3798
# 北京 31
# 京师 11957
# 九门 10638
# 集 1183
# 正阳门 3798
# 城楼 1430
# 正阳门 3798
# 箭楼 2922
# 正阳门 3798
# 瓮城 6264
# 一体 953
# 座 71
# 完整 685
# 古代 247
# 建筑 39
# 体系 6661
# 15075
# 花港 2834
# 观鱼 2001
# 景点 9
# 位 324
# 于苏堤 31968
# 南段 18361
# 建议 52
# 步行 230
# 苏堤 757
# 白堤 1244
# 时 99
# 观赏 478
# 下 43
# 太 42
# 喜欢 40
# 食物 1690
# 肥肥 27279
# 胖胖的 18362
# 31968
# 性价比 203
# 很高 383
# 383
# 玩 20
# 很好 24
# 风景 12
# 美丽 121
# 121
# 很好 24
# 美 11
# 值得 8
# 推荐 64
# 64
# 真是 143
# 不错 2
# 地方 5
# 尤其 256
# 好玩 105
# 256
# 野生动物园 1769
# 很好 24
# 1769
# 没啥 517
# 说 30
# 时间 26
# 试试 3234
# 步行 230
# 绕 676
# 西湖 36
# 三四 3177
# 小时 38
# 爽 1396
# 3234
# 晚上 58
# 夜景 254
# 一级 3753
# 棒 232
# 人 1
# 很漂亮 147
# 想 80
# 需要 77
# 花 192
# 80 525
# 元钱 3331
# 只能 155
# 看台 13577
# 观景 1415
# 感 755
# 不值 1006
# 知道 91
# 是不是 968
# 北京 31
# 市民 2374
# 收费 309
# 13577
# 不错 2
# 2
# 高大 1121
# 1121
# 本来 464
# 算是 294
# 热衷于 31969
# 游乐场 2457
# 人 1
# 貌似 1358
# 年龄 4625
# 有点 63
# 关系 1733
# 长 205
# 隆 1590
# 真的 21
# 难忘 1310
# 次 19
# 设施 246
# 齐全 1447
# 项目 184
# 非常丰富 8707
# 国内 745
# 数 1269
# 前 156
# 游乐场吧 38844
# 尤其 256
# 欢乐 1059
# 世界 102
# 隔壁 4052
# 大马 3532
# 戏 2045
# 更是 730
# 人 1
# 跟着 725
# 音乐 696
# 深入 2964
# 境 2091
# 38844
# 不错 2
# 地方 5
# 5
# 天 22
# 脊 625
# 龙门 540
# 风景区 283
# 国家级 1300
# 旅游景点 940
# 级吧 38845
# 还算 649
# 景区 7
# 很大 65
# 十 226
# 平方公里 1142
# 高山 850
# 特多 4001
# 一些 98
# 山区 2476
# 奇特 1317
# 景色 17
# 绝壁 1055
# 大峡谷 424
# 索桥 1586
# 飞 870
# 瀑布 119
# 人 1
# 惊叹 1868
# 飞 870
# 瀑布 119
# 第一 59
# 次 19
# 遇见 2030
# 以前 305
# 瀑布 119
# 普通 797
# 飞溅 8708
# 形式 2341
# 游览车 1977
# 玩 20
# 开心 114
# 38845
# 逛 106
# 逛 106
# 不够 643
# 里面 16
# 宅子 5276
# 感受到 619
# 山西 2835
# 智慧 563
# 5276
# 后山 750
# 门票 18
# 20 189
# 景色 17
# 优美 507
# 性价比 203
# 超高 3999
# 3999
# 九寨沟 240
# 美 11
# 已不 9260
# 需 991
# 说 30
# 次 19
# 往往 6662
# 很难 1163
# 玩遍 9579
# 九寨 739
# 四季 1613
# 变化 1720
# 景色 17
# 随之 19890
# 变化 1720
# 19890
# 般 273
# 273
# 本来 464
# 以为 542
# 进入 172
# 里边 1605
# 以后 213
# 古建筑 1091
# 物 2678
# 傻眼 19891
# 里边 1605
# 仅有 5743
# 一个 4
# 纪念碑 3235
# 保护 663
# 太 42
# 到位 2179
# 惊恐 14282
# 19891
# 最主要 2548
# 吃 70
# 最好 108
# 晚上 58
# 秦淮河 1038
# 美 11
# 喔 3299
# 人 1
# 影响 753
# 吃 70
# 东西 96
# 挺 56
# 特色 60
# 3299
# 周末 298
# 双休 18363
# 朋友 128
# 浪 1402
# 石金滩 2122
# 景区 7
# 旅游 57
# 规模 432
# 太大 450
# 游客 53
# 比较 13
# 看看 34
# 随后 4201
# 划船 829
# 好累 1600
# 有点 63
# 拥挤 1168
# 之后 162
# 的竹林 38846
# 海滨 5113
# 沙滩 627
# 跑马 3095
# 最好 108
# 玩 20
# 高尔夫球 3754
# 推荐 64
# 一下 69
# 38846
# 八大处 6403
# 里边 1605
# 幽静 879
# 看到 23
# 小松鼠 4626
# 跳来跳去 24181
# 随意 1574
# 找 178
# 地方 5
# 坐 37
# 下来 170
# 种 134
# 很好 24
# 享受 504
# 24181
# 座 71
# 山峰 683
# 形状 2031
# 像是 1037
# 猪八戒 11045
# 背 1942
# 媳妇 7126
# 11045
# 祈福 1683
# 话 190
# 建议 52
# 错峰 5195
# 风景 12
# 夏天 181
# 最 33
# 漂亮 94
# 5195
# 值得 8
# 年青人 27280
# 地方 5
# 艺术 274
# 气息 238
# 27280
# 大雁塔北广场 9912
# 占地面积 1658
# 很大 65
# 塔体 18364
# 高耸 4350
# 雄伟 548
# 晚上 58
# 音乐 696
# 喷泉 564
# 表演 142
# 好看 154
# 多彩 10639
# 变幻 6808
# 灯光效果 6809
# 更是 730
# 表演 142
# 增添 3533
# 唯美 5646
# 色彩 1357
# 18364
# 2008 2498
# 年 28
# 北京 31
# 奥运会 1523
# 之后 162
# 鸟巢 596
# 俨然 8477
# 成为 419
# 北京 31
# 标志 858
# 想 80
# 外观上 19892
# 一个 4
# 漂亮 94
# 鸟巢 596
# 一定 44
# 晚上 58
# 华灯初上 8045
# 夜景 254
# 迷人 856
# 想 80
# 真正 481
# 体验 126
# 鸟巢 596
# 找 178
# 比赛 2732
# 演出 456
# 走进 1076
# 看吧 5114
# 19892
# 乌镇 428
# 那天 451
# 住在 425
# 东 292
# 栅 296
# 景区 7
# 邻水 27281
# 感觉 10
# 不错 2
# 回去 1034
# 很晚 6156
# 天 22
# 下 43
# 大雪 3422
# 谢谢 3423
# 民宿 1636
# 老板 802
# 晚上 58
# 10 113
# 点 27
# 来接我 38847
# 38847
# 值得 8
# 地方 5
# 8
# 般 273
# 273
# 节假日 371
# 人 1
# 挤 588
# 人 1
# 说 30
# 节假日 371
# 别去 5449
# 5449
# 里头 5935
# 东西 96
# 景点 9
# 排队 83
# 玩 20
# 两 35
# 天 22
# 全部 708
# 玩 20
# 咯 1431
# 棒 232
# 累 109
# 腿脚 5744
# 肿 16001
# 饿 3424
# 16001
# 圣 5366
# 莲山 17057
# 位于 61
# 房山区 5196
# 史家营乡 38848
# 道教 761
# 圣地 673
# G 2941
# 108 4098
# 一路 149
# 西 276
# 行驶 4805
# 沿途 690
# 设有 3451
# 史家营 27282
# 圣 5366
# 莲山 17057
# 指 1721
# 路标 3671
# 路标 3671
# 行驶 4805
# 即可 976
# 道路 1069
# 通顺 38849
# 不堵车 9913
# 景区 7
# 面积 289
# 很大 65
# 门票 18
# 60 584
# 元 25
# 北京 31
# 风景 12
# 年票 4893
# 景点 9
# 售票员 3604
# 检票 2148
# 查看 7817
# 年票 4893
# 年票 4893
# 借着 9263
# 景区 7
# 门口 158
# 登山口 13578
# 距离 403
# 3.5 7286
# km 4154
# 上行 4155
# 爬坡 11046
# 选择 101
# 坐 37
# 景区 7
# 车 145
# 20 189
# 元 25
# 人 1
# 选择 101
# 自驾 568
# 停车费 3264
# 进入 172
# 费 2123
# 60 584
# 元 25
# 觉得 49
# 60 584
# 元 25
# 不值 1006
# 莲山 17057
# 人 1
# 景区 7
# 环境 84
# 清幽 1359
# 安静 400
# 舒适 1099
# 游客 53
# 基本会 19893
# 选择 101
# 十八盘 1397
# 爬山 103
# 上山 141
# 路程 1112
# 不算 469
# 远 353
# 不到 303
# 一个 4
# 小时 38
# 即可 976
# 到达 200
# 山顶 133
# 上山路 9264
# 比较 13
# 轻松 1035
# 遮阴 16002
# 半山腰 3534
# 一处 1888
# 值得 8
# 道观 2438
# 山顶 133
# 处 215
# 比较 13
# 古老 601
# 道观 2438
# 山顶 133
# 视野 1232
# 开阔 1056
# 能见度 4413
# 高 92
# 望见 8961
# 整个 124
# 圣 5366
# 莲山 17057
# 史家营 27282
# 风光 179
# 来到 197
# 圣 5366
# 莲山 17057
# 一定 44
# 坚持 1902
# 爬到 509
# 山顶 133
# 不枉 2477
# 此行 1667
# 下山可 17058
# 选择 101
# 原路 2390
# 返回 1002
# 走 15
# 条 93
# 下 43
# 山路 678
# 建议 52
# 走回头路 3300
# 一条路 2855
# 晒 1100
# 处 215
# 比较 13
# 险峻 1169
# 值得 8
# 风景 12
# 38849
# 不错 2
# 2
# 总 550
# 感觉 10
# 条 93
# 长长的 2499
# 路 160
# 是因为 803
# 苏轼 9265
# 变得 2836
# 与众不同 5647
# 节假日 371
# 长长的 2499
# 人 1
# 9265
# 舒服 320
# 安逸 3947
# 3947
# 影响 753
# 体验 126
# 753
# 江湾 3856
# 知道 91
# 伟人 2458
# 故乡 3672
# 深厚 2060
# 文化底蕴 1826
# 家族 3483
# 背景 2375
# 朝代 4569
# 数位 38850
# 高 92
# 官和 38851
# 商人 9266
# 38851
# 烧过 27283
# 香 956
# 工作日 3484
# 人 1
# 挺 56
# 27283
# 距离 403
# 市区 384
# 比较 13
# 远 353
# 坐车 528
# 小时 38
# 距离 403
# 兵马俑 260
# 不远 718
# 先 244
# 华清池 1517
# 再 62
# 过去 165
# 兵马俑 260
# 杨贵妃 3124
# 洗 2478
# 凝脂 27284
# 海棠 7287
# 汤 2785
# 打响 24182
# 西安 484
# 事变 8962
# 第一 59
# 枪 17059
# 地方 5
# 骊山 2160
# 下 43
# 兵谏亭 12441
# 只能 155
# 爬上去 585
# 路 160
# 有点 63
# 陡 762
# 坐 37
# 缆车 135
# 山顶 133
# 烽火台 4669
# 缆车 135
# 地点 874
# 不在 1534
# 正门 1495
# 坐上去 8963
# 27284
# 人 1
# 比较 13
# 只 107
# 门外 3535
# 稍稍 7818
# 两 35
# 眼 1933
# 感觉 10
# 应该 118
# 比较 13
# 看点 1722
# 7818
# aaabbbcccdddeeefffggg 21795
# 21795
# 刺激 275
# 275
# 建设 799
# 好 6
# 古镇 168
# 好 6
# 破坏 1666
# 太多 74
# 当地 221
# 居民 1448
# 住宿 319
# 居民 1448
# 热情 796
# 友好 6509
# 6509
# 好好 166
# 好好 166
# 好好 166
# 好好 166
# 好像 251
# 说话 3425
# 3425
# 黄山 67
# 光明 8709
# 顶风 24183
# 景 245
# 极好 2652
# 人 1
# 心情舒畅 7288
# 24183
# 总体 185
# 很好 24
# 185
# 黄山风景区 3033
# 景色 17
# 美丽 121
# 游客 53
# 3033
# 河坊街 1903
# 文艺 741
# 青年 2032
# 天堂 1018
# 里面 16
# 小 41
# 手工艺品 8243
# 种 134
# 欣赏 262
# 一个 4
# 小 41
# 店铺 1050
# 装饰 3096
# 风格 565
# 文艺 741
# 范 5197
# 十足 2894
# 8243
# 海边 1081
# 支 4099
# 帐篷 1631
# 吹风 9267
# 景 245
# 真的 21
# 惬意 530
# 9267
# 真的 21
# 般 273
# 般 273
# 般 273
# 般 273
# 273
# 还行 239
# 总体 185
# 来说 234
# 很大 65
# 歧视 24184
# 内地人 19894
# 24184
# 五一十一 18365
# 人 1
# 排队 83
# 碰 13579
# 喜欢 40
# 首付 31970
# 博物馆 266
# 感觉 10
# 31970
# 圣水 11958
# 禅院 8244
# 没啥 517
# 特别 29
# 寺庙 268
# 11958
# 五岳 489
# 归来 407
# 看山 963
# 黄山 67
# 归来 407
# 岳 882
# 冬天 223
# 的黄山 6973
# 白色 2206
# 蓝色 1564
# 交相 16003
# 呼应 6510
# 甚是 3426
# 美丽 121
# 云海 351
# 迎客松 1270
# 光明顶 950
# 猴子 499
# 观海 4738
# 景点 9
# 值得一看 255
# 坐 37
# 缆车 135
# 山 66
# 缆车 135
# 下山 164
# 方便 32
# 旅途 2679
# 中 51
# 偶遇 3857
# 黄山 67
# 小 41
# 猴子 499
# 成群结队 12971
# 挺 56
# 可爱 936
# 黄山 67
# 独特 490
# 风景线 6265
# 黄 1986
# 山脊 6511
# 16003
# 还行 239
# 239
# 必需 18366
# 说 30
# 布达拉宫 944
# 中国 48
# 瑰宝 3948
# 18366
# 避暑山庄 3949
# 全价 6512
# 票 55
# 145 15076
# 15076
# 不错 2
# 次 19
# 旅行 227
# 227
# 北京 31
# 了解 293
# 隐约 6513
# 记得 288
# 故宫 127
# 宫殿 875
# 名字 578
# 复杂 5367
# 外面 307
# 拦 4294
# 6513
# 距离 403
# 古北 3605
# 水镇 2786
# 一个 4
# 小时 38
# 车程 1632
# 两日游 4202
# 第二 140
# 天 22
# 选择 101
# 景区内 1254
# 主要 104
# 溪边 11047
# 小路 1504
# 水势 6663
# 小路 1504
# 蜿蜒 1565
# 曲折 2180
# 只 107
# 走 15
# 不到 303
# 分之一 3894
# 走到 301
# 尽头 2104
# 需要 77
# 小时 38
# 路线 376
# 上有 1360
# 小瀑布 4519
# 全程 467
# 树荫下 15077
# 比较 13
# 舒服 320
# 交通不便 9580
# 没什么 130
# 服务设施 4411
# 15077
# 感受 131
# 中国 48
# 古代 247
# 教育 904
# 文化 89
# 好 6
# 地方 5
# 周末 298
# 想 80
# 走走 411
# 国子监 2748
# 不错 2
# 选择 101
# 人 1
# 特别 29
# 天气 88
# 好 6
# 转转 1237
# 沉静 8710
# 一下 69
# 感受一下 898
# 古人 597
# 教育 904
# 环境 84
# 顺便 1311
# 转转 1237
# 周围 405
# 特色 60
# 小店 582
# 度过 5198
# 轻松 1035
# 休闲 277
# 周末 298
# 时光 1815
# 不错 2
# 8710
# 性价比 203
# 很高 383
# 感谢 2439
# 特价 10640
# 活动 472
# 10640
# 滨海 13580
# 小城 6664
# 宁静 992
# 一尘不染 16004
# 高速 1473
# 一路 149
# 穿山 7127
# 临海 4894
# 开 233
# 很爽 3097
# 16004
# 喀纳斯 1222
# 一直 129
# 特别 29
# 期待 726
# 地方 5
# 月份 784
# 不到 303
# 季节 308
# 山上 95
# 雪 494
# 应该 118
# 月份 784
# 再 62
# 肯定 659
# 特别 29
# 美 11
# 1222
# 不错 2
# 地方 5
# 值得 8
# 景点 9
# 需要 77
# 看好 2749
# 时间 26
# 有时候 2787
# 塔尔寺 1668
# 活动 472
# 暂停 15078
# 开放 279
# 15078
# 长途 8711
# 奔袭 38852
# 600 3301
# 公里 163
# 三清山 206
# 参加 2105
# 越野跑 38853
# 比赛 2732
# 比赛 2732
# 游览 112
# 景区 7
# 第一 59
# 次 19
# 尝试 1848
# 三清山 206
# 美不胜收 783
# 自然环境 6157
# 不亚于 7819
# 黄山 67
# 保护 663
# 好 6
# 尤其 256
# 长空 9914
# 栈道 225
# 步步 5648
# 美景 136
# 杜鹃花 3606
# 刚刚 2376
# 凋谢 18367
# 满地 6810
# 花瓣 11959
# 今年 1231
# 花 192
# 开得 5649
# 极好 2652
# 极盛 17060
# 越野跑 38853
# 说 30
# 今后 10641
# 38853
# 不到 303
# 老城 4203
# 不算 469
# 新疆 2391
# 老城 4203
# 特色 60
# 4203
# 物有所值 3140
# 3140
# 艺术 274
# 青年 2032
# 喜欢 40
# 地方 5
# 类似于 5450
# 群 859
# 喜欢 40
# 艺术 274
# 人 1
# 聚集 2500
# 地方 5
# 5450
# 周末游 7128
# 7128
# root 38854
# 群 859
# 女人 5451
# 涛 11048
# 学习 1259
# tyzxtokl 38855
# 继续 835
# 投 6665
# 38855
# 人 1
# 月中 3209
# 旬 4295
# 山 66
# 高 92
# 陡峭 946
# 次 19
# 缆车 135
# 天才 7289
# 够 734
# 山上 95
# 性价比 203
# 高 92
# 7289
# 美 11
# 美 11
# 祖国 2440
# 富强 27285
# 养 3858
# 百姓 5277
# 游 68
# 27285
# 刚刚 2376
# 拉萨 1456
# 回来 511
# 感觉 10
# 建筑 39
# 都好新 38856
# 后期 3178
# 修复 2272
# 方法 4156
# 觉得 49
# 合适 1107
# 整 1465
# 历史 47
# 味道 235
# 38856
# 普通 797
# 游客 53
# 常去 11049
# 长白山 1138
# 往往 6662
# 就是指 12442
# 长白山 1138
# 北坡 2317
# 相比 909
# 西坡 2501
# 容易 579
# 爬 78
# 北坡 2317
# 景点 9
# 更多 827
# 集中 1308
# 瀑布 119
# 温泉 560
# 小天池 5368
# 地下 1003
# 森林 787
# 皆 1964
# 建议 52
# 进 186
# 景区 7
# 后 50
# 先 244
# 山门 2502
# 乘坐 311
# 景区 7
# 巴士 1591
# 中转站 5745
# 购票 569
# 排队 83
# 越野车 5936
# 上山 141
# 天池 498
# 注意 389
# 加 792
# 件 876
# 衣服 899
# 租 367
# 当地 221
# 大衣 2707
# 下山 164
# 中转站 5745
# 后 50
# 步行 230
# 前往 470
# 观看 737
# 长白 4460
# 瀑布 119
# 途中 1486
# 聚 3897
# 龙泉 4895
# 观赏 478
# 五颜六色 3755
# 高温 7631
# 岩石 2061
# 泉 1723
# 品尝 1978
# 温泉 560
# 鸡蛋 4296
# 再 62
# 小天池 5368
# 游玩 75
# 静 2377
# 镜面 8964
# 小天池 5368
# 美景 136
# 最后 214
# 谷底 2441
# 林海 5937
# 石阶 2124
# 向下 4157
# 50 375
# 米 76
# 漫步 795
# 原始森林 1742
# 呼吸 1477
# 清新 740
# 富 7632
# 氧 7129
# 空气 177
# 整个 124
# 长白山 1138
# 北坡 2317
# 景区 7
# 游玩 75
# 圈 258
# 需要 77
# 一整天 1965
# 午餐 3298
# 只能 155
# 景区内 1254
# 解决 2171
# 结束 1189
# 游玩 75
# 后 50
# 再 62
# 坐 37
# 景区 7
# 巴士 1591
# 回到 877
# 山门 2502
# 12442
# 真的 21
# 壮观 86
# 后 50
# 海上 1290
# 山 66
# 住 153
# 晚 248
# 第二 140
# 大峡谷 424
# 下山 164
# 比较 13
# 轻松 1035
# 唯一 310
# 不足 2106
# 两 35
# 天 22
# 天气 88
# 很好 24
# 看到 23
# 日落 758
# 日出 138
# 听说 505
# 黄山 67
# 年 28
# 好 6
# 天气 88
# 看运气 6811
# 真的 21
# 美 11
# 一定 44
# 6811
# 值得 8
# 8
# 深圳 1788
# 一定 44
# 次 19
# 好看 154
# 美食 707
# 吃 70
# 1788
# 一句话 3673
# 概括 6812
# 人 1
# 太多 74
# 主要 104
# 人 1
# 6812
# 点评 187
# 有奖 219
# 12 242
# 季 210
# 点评 187
# 有奖 219
# 12 242
# 季 210
# 三清山 206
# 景区 7
# 名不虚传 813
# 风光 179
# 无限 1214
# 服务 180
# 棒棒 996
# 哒 867
# 1214
# 买票 207
# 方便 32
# 慈光 5369
# 阁 1178
# 门口 158
# 再买 6813
# 没有人 2247
# 前山 1238
# 爬上去 585
# 太 42
# 累 109
# 6813
# 很高 383
# 有兴趣 2417
# 话 190
# 爬上去 585
# 旁边 263
# 山水 604
# 2417
# 太棒 2318
# 好像 251
# 发现 216
# 新 553
# 大陆 4204
# 激动 1696
# 小镇 960
# 十分 259
# 宁静 992
# 那次 4670
# 下着 3332
# 小雨 1368
# 特别 29
# 美丽 121
# 4670
# 好 6
# 地方 5
# 好 6
# 风光 179
# 四川 1524
# 风景区 283
# 1524
# 月份 784
# 梅雨季节 18368
# 一起 110
# 衢州 600
# 天 22
# 脊 625
# 龙门 540
# 旅游 57
# 风景 12
# 人气 892
# 高山 850
# 大峡谷 424
# 绝壁 1055
# 飞 870
# 瀑布 119
# 索桥 1586
# 奇迹 1075
# 做 115
# 缆车 135
# 太 42
# 刺激 275
# 走索桥 13581
# 走到 301
# 中心 426
# 时刻 4100
# 感觉到 2135
# 景区 7
# 魅力 1061
# 所在 1505
# 18368
# 一群人 16005
# 打麻将 17061
# 17061
# 不错 2
# 2
# 号 151
# 温泉水 8240
# 目前 809
# 开放 279
# 游客 53
# 机会 250
# 装 3004
# 瓶 1614
# 回家 1837
# 8240
# 一个 4
# 小 41
# 公园 73
# 老年人 2389
# 门票 18
# 里面 16
# 皇 4245
# 穹宇 5199
# 圜丘坛 3674
# 回音壁 2125
# 看一看 1120
# 整个 124
# 建筑风格 1669
# 历史感 2181
# 数字 7820
# 讲究 3675
# 值得 8
# 感受 131
# 整个 124
# 公园 73
# 绿化 1522
# 好 6
# 北京 31
# 玩 20
# 累 109
# 慢慢 315
# 体验 126
# 不错 2
# 7820
# 夜场 2340
# 狂欢 12972
# 12972
# 极地 6814
# 动物 270
# 宝宝 1291
# 喜欢 40
# 买了 363
# 企鹅 7821
# 整天 11050
# 抱着 3564
# 11050
# 好 6
# 好 6
# 好 6
# 好 6
# 好 6
# 好 6
# 好 6
# 好 6
# 好 6
# 好 6
# 好 6
# 好 6
# 好 6
# 好 6
# 好 6
# 6
# 订票 446
# 总数 17062
# 2.1 24185
# 黄山风景区 3033
# 票 55
# 张 271
# 票 55
# 张 271
# 学生票 1200
# 张 271
# 成人 1749
# 票 55
# 计划 1170
# 有变 27286
# 取 167
# 张 271
# 成人 1749
# 票 55
# 当天 624
# 2.1 24185
# 早上 211
# 点 27
# 申请 8478
# 张 271
# 票 55
# 退款 6815
# 客服 4520
# 电话 2273
# 无数 1496
# 一直 129
# 没人接 19895
# 听 202
# 今天 444
# 时间 26
# 过期 16006
# 退 2479
# 钱 573
# 服务 180
# 人 1
# 堪忧 24186
# 一百 2248
# 票 55
# 普通 797
# 消 11960
# 27286
# 不错 2
# 2
# 好玩 105
# 105
# 风景 12
# 真是 143
# 错 1379
# 1379
# 真心 322
# 值得 8
# 著名 194
# 旅游景点 940
# 不到长城非好汉 1079
# 句话 4158
# 吸引 595
# 全世界 2813
# 各地 2126
# 游客 53
# 前来 2603
# 中国 48
# 千年 589
# 历史 47
# 仿佛 735
# 绵延起伏 38857
# 长城 174
# 烽火 12443
# 台中 38858
# 延续 8479
# 风景 12
# 很好 24
# 38858
# 喜欢 40
# 南塘 31971
# 吃货 2680
# 吃 70
# 地方 5
# 鼓楼 1633
# 城隍庙 2623
# 外滩 2681
# 美 11
# 酒吧 535
# 一条街 1278
# 咯 1431
# 不错 2
# 酒吧 535
# 31971
# 好 6
# 棒棒 996
# 驴妈妈 670
# 购物 1019
# 方便 32
# 1019
# 儿童 1525
# 情侣 1414
# 畅玩 27287
# 27287
# 木头 5278
# 变成 1347
# 石头 543
# 呵呵 607
# 硅化木 11961
# 国家 196
# 地质公园 2530
# 涨 4806
# 姿势 6514
# 11961
# 淳 17063
# 亲王 4461
# 允 17064
# 佑 12444
# 康熙皇帝 7463
# 子 779
# 雍正皇帝 11051
# 弟弟 7822
# 雍正 4002
# 元年 6404
# 晋封 38859
# 淳 17063
# 亲王 4461
# 淳 17063
# 亲王 4461
# 府 2222
# 受封 38860
# 淳 17063
# 亲王 4461
# 之后 162
# 建成 1171
# 位于 61
# 北京 31
# 东城区 2331
# 东交民巷 4965
# 正义路 31972
# 西侧 1716
# 至今 1151
# 建筑 39
# 保存 414
# 完好 1416
# 38860
# 烟袋斜街 3707
# 街道 860
# 很窄 5279
# 主要 104
# 经营 2895
# 旱烟袋 19896
# 水烟袋 19897
# 烟具 19898
# 古玩 5552
# 书画 6054
# 裱画 19899
# 文具 19900
# 风味小吃 9915
# 服务行业 19901
# 建筑风格 1669
# 朴素 5028
# 北京 31
# 北城 8712
# 特点 922
# 19901
# 奔 2965
# 西湖 36
# 围着 2589
# 西湖 36
# 步行 230
# 一大 500
# 圈 258
# 边走边看 9916
# 下午 193
# 点 27
# 转到 7633
# 点 27
# 最 33
# 忆 5839
# 杭州 79
# 表演 142
# 震撼 132
# 好 6
# 喜欢 40
# 杭州 79
# 西湖 36
# 9916
# 一定 44
# 早 449
# 449
# 不错 2
# <br 3
# >rn 14
# 风景 12
# 美 11
# <br 3
# >rn 14
# 再来 458
# 458
# 美好 562
# 562
# 0
# 租 367
# 条 93
# 船 393
# 水 97
# 干净 327
# 里面 16
# 洞里 4297
# 超 340
# 凉快 1601
# 有点 63
# 小 41
# 刺激 275
# 4297
# 环境 84
# 不错 2
# 84
# 古城 159
# 值得 8
# 保存 414
# 还算 649
# 完好 1416
# 物 2678
# 别是 19902
# 木楼 19903
# 相当 459
# 代表性 1966
# 重庆 2362
# 重庆 2362
# 木楼 19903
# 物以稀为贵 38861
# 满大街 11052
# 张飞 8713
# 牛肉 4414
# 醋泡脚 19904
# ------ 13582
# 价格 157
# 不贵 719
# 15 354
# 块 278
# 样子 631
# 逛 106
# 古城 159
# 累 109
# 街边 5115
# 随便 672
# 找 178
# 一家 394
# 泡泡 6266
# 加 792
# 按摩 16007
# 好像 251
# 30 191
# 块 278
# 舒服 320
# WIFI 18369
# 休息 385
# 一下 69
# 好 6
# 迎接 5650
# 后面 475
# 旅程 1762
# 卖 253
# 醋 5452
# 延 9268
# 滨江路 14283
# 大部分 785
# 已经改造成酒楼 38862
# 民宿 1636
# 看着 349
# 价格 157
# 便宜 175
# 费用 1315
# 有限 2814
# 亲们 4671
# 选择 101
# 古城 159
# 太远 2768
# 新城 14284
# 住现代 38863
# 酒店 330
# 挺 56
# 便宜 175
# 整体 378
# 古城 159
# 挺好玩 1133
# 38863
# 挺 56
# 美的 366
# 想象 280
# 中的 249
# 生活 321
# 奔波 14285
# 14285
# 驴妈妈 670
# 订票 446
# 方便 32
# 景区 7
# 好玩 105
# 开心 114
# 下次 212
# 想来 2161
# 玩 20
# 2161
# 算是 294
# 旅途 2679
# 中 51
# 次 19
# 停靠站 19905
# 住 153
# 夜 620
# 感受 131
# 城市 333
# 气息 238
# 喜欢 40
# 夜晚 715
# 游人 402
# 19905
# 冬天 223
# 树正沟 6405
# 挺 56
# 美的 366
# 推荐 64
# 芦苇海 5280
# 树正群 15079
# 海 436
# 火花 4672
# 海 436
# 15079
# 值得 8
# 8
# 梦幻 1215
# 童趣 6406
# 6406
# 男女老少 16008
# 休息 385
# 好 6
# 地方 5
# 山清水秀 1706
# 风景优美 705
# 空气质量 3898
# 好 6
# 值得 8
# 好 6
# 地方 5
# 16008
# 风景 12
# 很漂亮 147
# 空气 177
# 很好 24
# 177
# 有点 63
# 无聊 1778
# 1778
# 喜欢 40
# 古镇 168
# 水 97
# 喜欢 40
# 古老 601
# 喜欢 40
# 河水 3427
# 两边 765
# 古香古色 3607
# 房屋 2480
# 喜欢 40
# 幽静 879
# 走 15
# 古镇 168
# 里 46
# 享受 504
# 阳光 570
# 沐浴 5553
# 享受 504
# 空气清新 746
# 享受 504
# 生活 321
# ~~ 460
# 5553
# 拍 120
# 120
# 一家人 1798
# 开车 487
# 旅游 57
# 说 30
# 三清山 206
# 风景秀丽 791
# 风光 179
# 无限 1214
# 庐山 720
# 好玩 105
# 步 818
# 景 245
# 景观 228
# 各异 3950
# 人 1
# 感慨 2072
# 大自然 364
# 鬼斧神工 1009
# 造就 4159
# 美景 136
# 上山 141
# 坐 37
# 缆车 135
# 山上 95
# 走 15
# 挺 56
# 累 109
# 最好 108
# 小朋友 443
# 4159
# 庐山 720
# 半山腰 3534
# 一个 4
# 小镇 960
# 学校 1192
# 医院 6267
# 邮局 4462
# 菜场 21796
# 物价 2182
# 高 92
# 来庐山 21797
# 游玩 75
# 住 153
# 21797
# 受骗 18370
# 感觉 10
# 18370
# 第一 59
# 次登 11053
# 泰山 116
# 计划 1170
# 夜 620
# 登 680
# 目的 3034
# 日出 138
# 傍晚 952
# 下起 4415
# 蒙蒙细雨 6515
# 雨中登泰山 16009
# 一番滋味 5281
# 好像 251
# 影响 753
# 情绪 10642
# 点 27
# 登 680
# 一路 149
# 走走停停 1925
# 爬 78
# 晚上 58
# 观日 11054
# 峰 488
# 雨 374
# 停 844
# 找 178
# 地儿 3756
# 盼 17065
# 太阳能 27288
# 可惜 183
# 日出 138
# 时间 26
# 天空 768
# 云彩 8714
# 漂亮 94
# 27288
# 值得 8
# 8
# 黄山 67
# 庐山 720
# 中国 48
# 对外 6974
# 最大 171
# 两 35
# 自然 222
# 窗口 1289
# 风格 565
# 截然不同 11055
# 庐山 720
# 偏 1432
# 休闲 277
# 黄山 67
# 比较 13
# 耗费 6666
# 体力 347
# 总体 185
# 来说 234
# 名气 709
# 太大 450
# 容易 579
# 人 1
# 失望 377
# 比不上 5938
# 画 629
# 里面 16
# 座 71
# 平平常常 31973
# 山和 12445
# 真比 38864
# 38864
# 人 1
# 太多 74
# 74
# 不值 1006
# 1006
# 累 109
# 109
# 景点 9
# 美 11
# 价格 157
# 贵 90
# 人 1
# 太多 74
# 挤 588
# 不开 3528
# 3528
# 人 1
# 景点 9
# 洞 468
# 真心 322
# 般 273
# 468
# 0
# 市区 384
# 天门山 1265
# 景区 7
# 一个 4
# 热门 3141
# 景区 7
# 游玩 75
# 天 22
# 时间 26
# 天门 1043
# 洞 468
# 玻璃 508
# 栈道 225
# 天门山 1265
# 索道 87
# 天门 1043
# 山 66
# 国家森林公园 1223
# 张家界 302
# 最 33
# 值得 8
# 国家 196
# 级 286
# 景区 7
# 3141
# 南山 1179
# 一日游 345
# 1179
# 人 1
# 比较 13
# 没什么 130
# 不好 281
# 早 449
# 449
# 景色 17
# 美 11
# 错峰 5195
# 出游 252
# 人 1
# 太 42
# 潮 2392
# 湿 3394
# 月份 784
# 潮湿 5200
# 忍忍 38865
# 好 6
# 38865
# 美得 2033
# 童话故事 24187
# 入眼 13583
# 处 215
# 景 245
# 24187
# 最 33
# 愿意 2788
# 提起 9269
# 景区 7
# 9269
# 当年 418
# 大学 923
# 姐妹 6407
# 坐车去 4896
# 游玩 75
# 山路 678
# 九曲十八弯 10281
# 好 6
# 担心 1743
# 抛 8715
# 下山 164
# 呵呵 607
# 10281
# 不错 2
# 累 109
# 点 27
# 109
# 景区 7
# 不错 2
# 人 1
# 太多 74
# 74
# 大兴 9270
# 野生动物园 1769
# 9270
# 广州塔 4416
# 夜景 254
# 4416
# 北京 31
# 故宫 127
# 故宫 127
# 看看 34
# 知道 91
# 现在 72
# 电视剧 1799
# 拍 120
# 狗血 27289
# 27289
# 景色 17
# 17
# 想 80
# 动物 270
# 合适 1107
# 去处 2092
# 动物 270
# 应有尽有 4003
# 4003
# 挺好 161
# 161
# 阴天 1487
# 晴天 1025
# 完全 264
# 风景 12
# 看山 963
# 张家界 302
# 1487
# 月 100
# 15 354
# 日 199
# 门票 18
# 元 25
# 登上 677
# 万春亭 11478
# 俯瞰 630
# 故宫 127
# 全景 736
# 傍晚 952
# 站 169
# 上面 236
# 夕阳 1967
# 美 11
# 11478
# 每天晚上 9581
# 两场 31974
# 温泉 560
# 一定 44
# 提前 306
# 排队 83
# 争取 11962
# 两 35
# 排 409
# 位置 348
# 31974
# 山 66
# 不在 1534
# 高 92
# 仙 1827
# 名 575
# 海拔 342
# 164 24188
# 米 76
# 烂柯山 1615
# 成 300
# 此言 21798
# 好 6
# 注脚 38866
# 山含 38867
# 翠黛 38868
# 涧 3142
# 泉流 21799
# 彩 4417
# 石梁 5651
# 惊 5029
# 虹 11479
# 空谷传声 27290
# 神仙 3536
# 世界 102
# 烂柯山 1615
# 曾令 38869
# 无数 1496
# 古人 597
# 陶醉 4807
# 泛泛 38870
# 今人 12446
# 向往 1245
# 柯 9271
# 烂 2114
# 名 575
# 不朽 19906
# 美哉 14286
# 烂柯山 1615
# 38870
# 不错 2
# 2
# 艺术 274
# 气息 238
# 地方 5
# 进到 3452
# 画展 8245
# 里 46
# 安静 400
# 静静地 3859
# 欣赏 262
# 幅 941
# 画 629
# 艺术 274
# 区内 5030
# 设计 710
# 新颖 8246
# 喜欢 40
# 摄像 17066
# 拍照 117
# 17066
# 龙峪湾 31975
# 印象 217
# 31975
# 美 11
# 美 11
# 时间 26
# 再 62
# 从前 4160
# 爬越 27291
# 天都峰 1422
# 27291
# 有意思 410
# 古人 597
# 太 42
# 厉害 1535
# 震撼 132
# 1535
# 气势 689
# 恢弘 2653
# 安静 400
# 人 1
# 挺 56
# 书籍 8046
# 8046
# 古人 597
# 现在 72
# 发达 4298
# 工具 6667
# 却 243
# 鬼斧神工 1009
# 6667
# 雄伟壮观 1838
# 每个 335
# 北京 31
# 人 1
# 应该 118
# 1838
# 阳光 570
# 下 43
# 金碧辉煌 2549
# 登 680
# 许久 8247
# 的山 2073
# 终于 572
# 停下来 3708
# 打望 31976
# 地方 5
# 31976
# 景山 2342
# 位于 61
# 故宫 127
# 正后方 27292
# 地处 1403
# 当年 418
# 景山 2342
# 炮轰 38871
# 紫禁城 1195
# 38871
# 第一 59
# 次 19
# 关顾 38872
# 黄山 67
# 上山 141
# 索道 87
# 方便 32
# 来回 969
# 收费 309
# 还好 295
# 驴妈妈 670
# 便宜 175
# 38872
# 永福 5939
# 寺 519
# 包含 1098
# 飞来峰 1552
# 一体 953
# 门票 18
# 里 46
# 名气 709
# 灵隐寺 634
# 小 41
# 值得 8
# 山路 678
# 走 15
# 路上 291
# 人 1
# 漫山 8965
# 郁郁葱葱 3066
# 溪流 2304
# 寺庙 268
# 翠竹 9272
# 登上 677
# 顶峰 3333
# 俯瞰 630
# 十八景 10643
# 值得 8
# 错过 482
# 10643
# 很好 24
# 景点 9
# 很好 24
# 景点 9
# 很好 24
# 景点 9
# 很好 24
# 景点 9
# 很好 24
# 景点 9
# 很好 24
# 景点 9
# 24
# 值得一看 255
# 震撼人心 5282
# 夜 620
# 冷 566
# 往往 6662
# 意外 2034
# 收获 1869
# 6662
# 曾经 723
# 领导人 3265
# 居住 1015
# 办公 4570
# 地方 5
# 很漂亮 147
# 园林绿化 24189
# 很好 24
# 24189
# 酒店 330
# 位置 348
# 很好 24
# 漓江 1101
# 精华 957
# 段 304
# 出门 1417
# 漂流 888
# 20 189
# 元 25
# 人民币 2708
# 每个 335
# 房间 1047
# 布置 3302
# 特色 60
# 温馨 3303
# 卫生间 3125
# 很大 65
# 干净 327
# wifi 8480
# 信号 7130
# 很好 24
# 房间 1047
# 小 41
# 阳台 7823
# 坐在 703
# 阳台 7823
# 吃 70
# 送 1284
# 西瓜 7464
# 舒服 320
# 惬意 530
# 住 153
# 景观 228
# 房 1697
# 顶楼 10644
# 阳台 7823
# 景色 17
# 相当 459
# 好 6
# 10644
# 西湖 36
# 边上 609
# 处 215
# 景点 9
# 山 66
# 高 92
# 用时 4299
# 4299
# 综合 3951
# 体验 126
# 不错 2
# 风景 12
# 美 11
# 值得 8
# 3951
# 总 550
# 感觉 10
# 药王山 621
# 次 19
# 比较 13
# 好 6
# 想 80
# 非常适合 1579
# 年轻 3359
# 人 1
# 走走 411
# 3359
# 建议 52
# 游船 463
# 那次 4670
# 时间 26
# 下午 193
# 点 27
# 停止 4418
# 售 9273
# 船票 1621
# 建议 52
# 提前 306
# 买票 207
# 周边 379
# 住宿 319
# 方便 32
# 三潭 3565
# 映 2393
# 月 100
# 断桥 551
# 残雪 1878
# 坐船 532
# 感触 3608
# 更多 827
# 一些 98
# 累 109
# 西湖 36
# 真的 21
# 太大 450
# 9273
# 杭州 79
# 遇到 531
# 卖 253
# 咸亨酒店 8481
# 茴香豆 9917
# 宝贝 3641
# 般的 1913
# 买回来 24190
# 路上 291
# 细细地 18371
# 嚼 17067
# 想起 1441
# 鲁迅 766
# 社戏 17068
# 故乡 3672
# 觉得 49
# 乌蓬船 21800
# 中的 249
# 一个 4
# 曾 644
# 偷 9582
# 公 3143
# 公家 31977
# 岸边 2249
# 煮 7290
# 吃 70
# 似乎 1172
# 三味书屋 3334
# 念书 38873
# 放学后 38874
# 蹲 8966
# 百草园 2481
# 堵 2250
# 矮 10645
# 墙下 27293
# 听 202
# 蟋蟀 38875
# 弹琴 21801
# 一时间 14287
# 心里 1275
# 涌出 16010
# 许多 397
# 温馨 3303
# 许多 397
# 惆怅 18372
# 38875
# 朱家尖 4808
# 国家级 1300
# 风景 12
# 名胜区 937
# 位于 61
# 浙江省 1404
# 舟山群岛 7465
# 东南部 5940
# 相距 6158
# 海里 6055
# 海天 4966
# 佛国 4101
# 普陀山 1466
# 并称 2062
# 普陀山 1466
# 国家级 1300
# 重点 486
# 风景 12
# 名胜区 937
# 舟山群岛 7465
# 核心 1698
# 旅游区 1684
# 普陀 3566
# 金三角 16011
# 重要 433
# 组成部分 4053
# 舟山群岛 7465
# 五大 2378
# 岛 545
# 岛屿 2074
# 面积 289
# 72 4739
# 平方公里 1142
# 风景区 283
# 创建 3126
# 优秀 5370
# 景区 7
# 重视 8482
# 旅游 57
# 文化 89
# 建设 799
# 已经 85
# 成为 419
# 中国 48
# 华东地区 14288
# 最 33
# 活力 7824
# 海滨 5113
# 旅游胜地 3210
# 16011
# 登上 677
# 顶部 4897
# 俯览 17069
# 整个 124
# 鼓浪屿 441
# 视野 1232
# 开阔 1056
# 景色 17
# 美 11
# 17069
# 这种 338
# 私家园林 4809
# 一两 2789
# 看看 34
# 觉得 49
# 反正 865
# 看看 34
# 假山 2733
# 景观 228
# 逛一逛 3335
# 有意思 410
# 4809
# 圆明园 556
# 十二生肖 8716
# 首 1408
# 海 436
# 回来 511
# 迷宫 4004
# 原来 538
# 圆明园 556
# 桥 312
# 后面 475
# 新建 1763
# 十二生肖 8716
# 兽 6816
# 守 6056
# 原先 5941
# 摆放 11963
# 位置 348
# 夕阳 1967
# 太 42
# 漂亮 94
# 冷风 9274
# 过境 21802
# 后 50
# 才有 7131
# 美景 136
# 北京 31
# 吹 1807
# 糖人 18373
# D 1592
# 十三陵 2569
# 21802
# 风景如画 1385
# 特别 29
# 红石峡 8967
# 真 357
# 可谓 2709
# 步 818
# 景 245
# 移步 5942
# 移景 18374
# 景区 7
# 商家 3030
# 服务 180
# 改善 4205
# 河南 4005
# 境内 1299
# 景区 7
# 18374
# 只 107
# 外面 307
# 看过 807
# 看过 807
# 演出 456
# 遗憾 261
# 807
# 泰山 116
# 景色 17
# 美 11
# 爬山 103
# 太 42
# 累 109
# 天外村 2624
# 爬到 509
# 山顶 133
# 一直 129
# 走 15
# 下来 170
# 封禅 2379
# 大典 3035
# 壮观 86
# 很漂亮 147
# 3035
# 前山 1238
# 景区 7
# 道观 2438
# 文化 89
# 历史 47
# 为主 771
# 不错 2
# 值得 8
# <br 3
# 2438
# 站 169
# 天子 2223
# 观景台 1012
# 三千 6408
# 奇峰 2019
# 尽收眼底 1691
# 6408
# 上野 17070
# 一日游 345
# 17070
# 包车 1146
# 游览 112
# 游客 53
# 能够 890
# 司机 606
# 感兴趣 1593
# 地方 5
# 随时 3421
# 停车 947
# 增加 2790
# 旅途 2679
# 弹性 31978
# 趣味性 3860
# 塔尔寺 1668
# 位于 61
# 湟中县 24191
# 鲁沙尔镇 31979
# 坐落 1105
# 莲花山 18375
# 中 51
# 距 780
# 西宁市 19907
# 25 1082
# 公里 163
# 格鲁派 7634
# 创始人 8248
# 宗喀巴 11480
# 大师 2380
# 诞生地 11056
# 已有 4300
# 640 17071
# 多年 648
# 历史 47
# 1961 4967
# 年 28
# 授予 11057
# 国家 196
# 重点 486
# 文物保护 1048
# 单位 911
# 2013 3395
# 年 28
# 评为 3139
# 国家 196
# 级 286
# 旅游 57
# 景区 7
# 31979
# 喜欢 40
# 东方明珠 2224
# 玻璃 508
# 栈道 225
# 刺激 275
# 好看 154
# 2224
# 北海公园 1734
# 印象 217
# 很深 2769
# 进 186
# 大门 567
# 远远望去 6057
# 看见 297
# 白色 2206
# 坐船 532
# 游 68
# 公园 73
# 挺好 161
# 美 11
# 6057
# 喜欢 40
# 中国 48
# 景点 9
# 这种 338
# 圈钱 16012
# 收费 309
# 行为 6058
# 别去 5449
# 坐电梯 4968
# 16012
# 华山 1182
# 难忘 1310
# 记忆 1083
# 连夜 21803
# 登山 491
# 考验 3676
# 体力 347
# 耐力 11964
# 日出 138
# 地方 5
# 日出 138
# 期待 726
# 心情 396
# 却是 2162
# 相同 5453
# 华山 1182
# 日出 138
# 并不 902
# 惊艳 1285
# 守 6056
# 慢慢 315
# 出现 1077
# 眼前 1108
# 满满的 2107
# 感动 2940
# 21803
# 整体 378
# 描绘出 24192
# 鲁迅 766
# 生活 321
# 居所 10646
# 身份证 267
# 入 299
# 园 329
# 体验 126
# 下 43
# 不错 2
# 课本上 5454
# 记忆 1083
# 蹭 1086
# 蹭 1086
# 蹭 1086
# 外 369
# 24192
# 只能 155
# 说 30
# 地标 724
# 建筑 39
# 人 1
# 随便 672
# 看看 34
# 724
# 不错 2
# 第一 59
# 次 19
# 开车 487
# 路线 376
# 487
# 休闲 277
# 话 190
# 还算 649
# 不错 2
# 干净 327
# 园子 926
# 926
# 一定 44
# 地方 5
# 44
# 十一 759
# 假期 900
# 人山人海 622
# 人山人海 622
# 900
# 昌平 4673
# 西部 2183
# 山区 2476
# 北京 31
# 城区 1808
# 60 584
# 公里 163
# 庙会 2625
# 妙峰山 8717
# 道教 761
# 文化 89
# 圣地 673
# <br 3
# >n 45
# 8717
# 还行 239
# 239
# 特色 60
# 的大桥 18376
# 之前 204
# 觉得 49
# 跨海大桥 5840
# 壮观 86
# 桥 312
# 之前 204
# 一直 129
# 了解 293
# 远远 1594
# 眼 1933
# 导游 81
# 姐姐 4463
# 说 30
# 座 71
# 桥 312
# 上面 236
# 开汽车 38876
# 下面 506
# NICE 27294
# 38876
# 千古情 1423
# 演出 456
# 值得一看 255
# 1423
# 海鲜 1334
# 极好 2652
# 海城市 27295
# 真 357
# 幸福 2330
# 27295
# 轻松愉快 9583
# 高性价比 19908
# 之旅 380
# 19908
# 票价 284
# 贵 90
# 满意 465
# 465
# 不错 2
# 2
# 物超所值 5116
# 5116
# 共有 2815
# 出名 691
# 天池 498
# 一个 4
# 长白山天池 6159
# 一个 4
# 新疆 2391
# 天山天池 6516
# 长白山天池 6159
# 出名 691
# 一些 98
# 观赏 478
# 朋友 128
# 最多 945
# <br 3
# >rn 14
# 长白山天池 6159
# 座 71
# 休眠火山 38877
# 火山口 6975
# 积水 9275
# 成 300
# 湖 224
# 池水 4674
# 湛蓝 4571
# 冬 3098
# 冻冰 14289
# 面 526
# 冬天 223
# 来到 197
# 只 107
# 看到 23
# 片 231
# 雪白 9918
# 当时 188
# 遗憾 261
# 说 30
# 来到 197
# 长白山 1138
# 费劲 5652
# 却 243
# 看到 23
# 一个 4
# 冻住 11481
# 湖面 577
# 第二 140
# 天 22
# 下 43
# 大雪 3422
# 部分 503
# 同行 2682
# 朋友 128
# 看到 23
# 原来 538
# 这时候 5455
# 知道 91
# 登陆 31980
# 天气 88
# 不错 2
# 很大 65
# 幸运 1515
# <br 3
# >rn 14
# 天池 498
# 却 243
# 一番 546
# 景色 17
# 天池 498
# 夹 4161
# 山顶 133
# 之中 977
# 小姑娘 6976
# 冬天 223
# 羞涩 11965
# 真的 21
# 好看 154
# 天池 498
# 俯瞰 630
# 整个 124
# 长白山 1138
# 放眼望去 6517
# 片 231
# 白雪皑皑 5456
# 真的 21
# 好 6
# 美好 562
# 美 11
# <br 3
# >rn 14
# 交通 176
# 长白山 1138
# 景区 7
# 乘坐 311
# 观光车 714
# 天池 498
# 观光 514
# 车 145
# 换乘 1800
# 地方 5
# 再 62
# 掏 8718
# 85 4301
# 买 82
# 天池 498
# 观光 514
# 车票 1122
# 直接 111
# 送到 2750
# 天池 498
# 景点 9
# 回来 511
# 乘坐 311
# 同样 1951
# 车 145
# <br 3
# >rn 14
# 祝 5457
# 天池 498
# 看到 23
# 看到 23
# 美 11
# 的天池 12973
# 38877
# 空调 2816
# 舒服 320
# 点 27
# 能登 31981
# 岛 545
# 完美 639
# 31981
# 海洋馆 2734
# 不错 2
# 海里 6055
# 生命 3709
# 一应俱全 6518
# 特殊 1860
# 应该 118
# 看到 23
# 海底世界里 31982
# 小丑鱼 38878
# 调皮 4302
# 看到 23
# 黑黑的 24193
# 看不到 541
# 眼睛 2673
# 海胆 21804
# 浑身 9919
# 长 205
# 尖 6668
# 刺 17072
# 看到 23
# 觉得 49
# 浑身 9919
# 不自在 38879
# 漂亮 94
# 柔软 8483
# 水母 8719
# 小 41
# 鲨鱼 31983
# 海龟 19909
# 海狮 6059
# 海狮 6059
# 表演 142
# 精彩 591
# 大笑 3179
# 38879
# 北京植物园 6519
# 里面 16
# 植物 702
# 6519
# 风景 12
# 不错 2
# 12
# 赞 152
# 项目 184
# 设施 246
# 精彩 591
# 周末 298
# 人 1
# 太多 74
# 排队 83
# 排 409
# 久 2319
# 玩 20
# 不到 303
# 项目 184
# 比较 13
# 遗憾 261
# <br 3
# >n 45
# 2319
# 附近 148
# 很多酒吧 9920
# 听说 505
# 明星 4054
# 9920
# 景色 17
# 美 11
# 17
# 挺好 161
# 161
# 全程 467
# 爬山 103
# 467
# 下 43
# 孔家 21805
# 儒家 11482
# 鼻祖 11483
# 21805
# 滴滴 5117
# 过去 165
# 十几 1497
# 门票 18
# 门口 158
# 卖 253
# 105 8047
# 提前 306
# 天 22
# 订 754
# 门口 158
# 买了 363
# 天气 88
# 暴雨 3642
# 淹 12974
# 水位 5746
# 超过 2016
# 警戒线 31984
# 只能 155
# 游湖 4627
# 路上 291
# 见到 742
# 小龙虾 8720
# 31984
# 山上 95
# 水库 1484
# 1484
# 莲花峰 3144
# 位于 61
# 玉屏楼 7825
# 北 390
# 黄山 67
# 第一 59
# 高峰 1659
# 海拔 342
# 1864 19910
# 米 76
# 峻峭 10282
# 高耸 4350
# 气势雄伟 3485
# 宛如 2251
# 初绽 31985
# 莲花 2837
# 故名 2288
# 莲花 2837
# 岭 1952
# 莲花 2837
# 峰顶 3428
# 约 285
# 1.5 2456
# km 4154
# 这段 2332
# 路 160
# 莲花 2837
# 梗 27296
# 沿途 690
# 飞龙 6817
# 松 801
# 倒挂 27297
# 名 575
# 松 801
# 黄山 67
# 杜 12447
# 鹃 17073
# 莲花峰 3144
# 处 215
# 方圆 8249
# 丈 3677
# 余 970
# 中间 555
# 井 5841
# 置身 3236
# 峰顶 3428
# 遥望 6268
# 四方 4675
# 千峰 38880
# 竞秀 12448
# 万壑 38881
# 生 1498
# 烟 4419
# 万 1362
# 38881
# 一部分 1338
# 很旧 19911
# 应该 118
# 原来 538
# 另有 6818
# 一部分 1338
# 新 553
# 盖 2289
# 气势 689
# 旧 1685
# 婉约 6977
# 喜欢 40
# 小 41
# 池里 16013
# 大鱼 11058
# 兵马俑 260
# 一条线 5554
# 西安 484
# 出发 422
# 车子 2225
# 先 244
# 华清池 1517
# 后 50
# 兵马俑 260
# 兵马俑 260
# 加 792
# 秦 2394
# 皇陵 3453
# 比较 13
# 费时 18377
# 华清池 1517
# 好 6
# 把握 7826
# 时间 26
# 先 244
# 兵马俑 260
# 19911
# 好 6
# 主题公园 1987
# 1987
# 之前 204
# 朋友 128
# 推荐 64
# 总体 185
# 感觉 10
# 不错 2
# 环境 84
# 最主要 2548
# 正 1292
# 好人 8250
# 高峰 1659
# 估计 557
# 惨 6269
# 泡 2163
# 完 438
# 之后 162
# 楼上 3145
# 休闲娱乐 6819
# 健身 2093
# 完善 1260
# 有待 2856
# 加强 4162
# 自驾 568
# 一路 149
# 跟着 725
# 导航 2172
# 走 15
# 上海 287
# 出发 422
# 只用 7132
# 小时 38
# 晚上 58
# 泡 2163
# 温泉 560
# 周五 5458
# 人 1
# 工作人员 434
# 说 30
# 周六 3036
# 周日 5555
# 爆满 8048
# 特别 29
# 周六 3036
# 天 22
# 接待量 27298
# 最高 523
# 持 4572
# 平 4464
# 周 1634
# 时间 26
# 接待量 27298
# 总和 38882
# 过年 1979
# 每天 656
# 接待 3486
# 千人 8049
# 次 19
# 下 43
# 饺子 7827
# 每个 335
# 汤池 8050
# 爆满 8048
# 室内 1861
# 两 35
# 汤 2785
# 一个 4
# 鱼 1004
# 疗 19912
# 汤池 8050
# 水温 9584
# 较低 7828
# 一个 4
# 水温 9584
# 特高 27299
# 估计 557
# 适应 7466
# 过度 2966
# 真正 481
# 泡汤 10283
# 室外 3146
# 室外 3146
# 12 242
# 14 452
# 汤池 8050
# 红酒 17074
# 池 2570
# 中药 12449
# 池 2570
# 花瓣 11959
# 池 2570
# 咖啡 3127
# 池 2570
# 太多 74
# 记不住 11484
# 38882
# 元旦 2290
# 天气 88
# 冷 566
# 湖面 577
# 已 474
# 结冰 2942
# 周边 379
# 山峰 683
# 裸露 17075
# 岩石 2061
# 树干 14290
# 山头 3861
# 洒 6060
# 层 313
# 稀稀疏疏 31986
# 白雪 4102
# 牛角 21806
# 面包 5943
# 点缀 3211
# 31986
# 杭州 79
# 动 3067
# 车站 1606
# 算是 294
# 交通 176
# 繁华 841
# 地方 5
# 预计 7812
# 杭州 79
# 时间 26
# 晚 248
# 两 35
# 小时 38
# 出站 3037
# 后 50
# 本来 464
# 打车 1020
# 青旅 3537
# 人 1
# 太多 74
# 车 145
# 太少 1839
# 最后 214
# 搭乘 2654
# 公交车 392
# 7812
# 想去 386
# 拦 4294
# 平常心 24194
# 平常心 24194
# 24194
# 棒 232
# 次 19
# 旅行 227
# 值得 8
# 正好 493
# 山 66
# 里面 16
# 热 448
# 山上 95
# 住 153
# 晚 248
# 一览 951
# 众山 1474
# 小 41
# 险峻 1169
# 陡峭 946
# 爬 78
# 完 438
# 黄山 67
# 回来 511
# 累 109
# 趴 6820
# 选择 101
# 慈光 5369
# 阁 1178
# 步行 230
# 上山 141
# 一路 149
# 勇往直前 38883
# 38883
# 值得 8
# 自然风光 864
# 超级 201
# 漂亮 94
# 景点 9
# 864
# 没劲 7133
# 7133
# 点评 187
# 有奖 219
# 13 958
# 季 210
# 很高 383
# 壮观 86
# 宏伟 513
# 感受到 619
# 渺小 4465
# 4465
# 壮观 86
# 眼里 7829
# 风景 12
# 太多 74
# 雷同 11059
# 11059
# 满足 1750
# 少女心 11966
# 11966
# 凌晨 2442
# 点 27
# 列车员 31987
# 叫醒 18378
# 爬下 14291
# 床铺 21807
# 觉得 49
# 冷 566
# 裹 10284
# 棉被 38884
# 坐在 703
# 窗边 18379
# 外面 307
# 景物 4573
# 惊呆 8484
# 时间 26
# 太早 3531
# 景物 4573
# 风景 12
# 独特 490
# 仿佛 735
# 穿越 938
# 一个 4
# 世界 102
# 觉得 49
# 下 43
# 秒 3799
# 史前 8251
# 怪兽 19913
# 出现 1077
# 下 43
# 火车 398
# 乘上 18380
# 公交 328
# 到达 200
# 三姑 38885
# 度假村 6520
# 找到 544
# 住处 8721
# 听说 505
# 前 156
# 晚 248
# 下过 3609
# 暴雨 3642
# 山间 1816
# 雾气 1424
# 朦胧 2710
# 仿若 10285
# 仙境 453
# 景区 7
# 分开 3800
# 描述 2604
# 有一点 2943
# 人力 6521
# 小三轮 24195
# 太多 74
# 缠着 18381
# 人 1
# 问 580
# 不停 1968
# 拒绝 6978
# 还跟着 38886
# 人 1
# 无奈 2791
# 38886
# 九溪 1789
# 小溪流 19914
# 龙井村 2986
# 一路 149
# 走 15
# 下来 170
# 超 340
# 棒 232
# 建议 52
# 穿 533
# 拖鞋 5556
# 备 5459
# 双 2207
# 水 97
# 凉爽 1233
# 重点 486
# 两 35
# 地方 5
# 用钱 15080
# 避暑 993
# 好 6
# 地方 5
# 19914
# 早就 2395
# 听闻 4206
# 老子 6061
# 此地 2274
# 列为 3180
# 福建 3952
# 泉州 12450
# 之行 885
# 必选 9585
# 动作 7830
# 实话 11967
# 说 30
# 山中 2305
# 老子 6061
# 相对于 3266
# 曾经 723
# 图片 1149
# 中 51
# 看到 23
# 恢宏 4466
# 实在 269
# 小 41
# 最大 171
# 老子 6061
# 坐像 8968
# 估算 24196
# 一下 69
# 超过 2016
# 米 76
# 岁月 2896
# 身上 3336
# 留下 608
# 笔笔 38887
# 斑驳 4467
# 尽显 7467
# 沧桑 2271
# 感 755
# 当时 188
# 人群 1386
# 确实 139
# 熙熙攘攘 4628
# 照相 1224
# 难以 4629
# 考虑 1660
# 构图 19915
# 只能 155
# 老子 6061
# 相片 8722
# 底 1980
# 老子 6061
# 清源山 11968
# 玄奘 5550
# 诸多 5548
# 遗迹 1575
# 听 202
# 颇具 7134
# 沧桑 2271
# 景点 9
# 名称 3181
# 前天 10647
# 的钟楼 31988
# 肉粽 17076
# 准备 561
# 登山 491
# 突然 1914
# 肠胃 31989
# 工 4521
# 预想 8723
# 登顶 1032
# 清源 31990
# 天湖 5944
# 只能 155
# 留待 27300
# 下次 212
# 算是 294
# 此行 1667
# 一个 4
# 小 41
# 遗憾 261
# 38887
# 太阳岛 3267
# 公园 73
# 一个 4
# 市内 3487
# 比较 13
# 公园 73
# 很大 65
# 根本 602
# 不用 182
# 坐 37
# 电瓶车 614
# 松鼠 2455
# 园 329
# 天鹅湖 8958
# 些许 3757
# 动物 270
# 景色 17
# 名声在外 6270
# 8958
# 爱 471
# 晚 248
# 亭 674
# 坐落 1105
# 岳麓山 1065
# 认识 2252
# 源于 6821
# 著名 194
# 诗句 4246
# 6821
# 世界公园 4676
# 北京市 336
# 精致 675
# 使 903
# 人 1
# 惊奇 6669
# 地方 5
# 拥有 1616
# 世界级 6062
# 风格 565
# 6669
# 点评 187
# 有奖 219
# 13 958
# 季 210
# 精彩 591
# 表演 142
# 演出 456
# 外国人 2605
# 演出 456
# 好几 763
# 15 354
# 岁 671
# 小伙子 8724
# 真的 21
# 台上 6522
# 分钟 173
# 台下 12975
# 十 226
# 年 28
# 功 15081
# 演出 456
# 中西合璧 7459
# 表演 142
# 经典 697
# 国外 3899
# 花样 38888
# 摩托车 5945
# 跷跷板 38889
# 演员 3538
# 幽默 12451
# 有趣 636
# 驴妈妈 670
# 票 55
# 现场 747
# 买 82
# 便宜 175
# 100一 17077
# 张 271
# 1.1 21808
# 以下 2136
# 38889
# 真的 21
# 好 6
# 震撼 132
# 孩子 123
# 喜欢 40
# 机会 250
# 次 19
# 250
# 摄影 1087
# 爱好者 1457
# 圣地 673
# 天气 88
# 晴朗 2396
# 雪后 3758
# 冰封 10648
# 奇特 1317
# 天象 12976
# 严谨 8051
# 对称 4969
# 摄影 1087
# 爱好者 1457
# 聚集地 3710
# 12976
# 看看 34
# 34
# 渔山 21809
# 岛 545
# 不错 2
# 算是 294
# 比较 13
# 原生态 2094
# 岛屿 2074
# 岛 545
# 小时 38
# 绕 676
# 圈 258
# 玩 20
# 一个 4
# 周末 298
# 足矣 4970
# 21809
# 大观园 3900
# 3900
# 樱花节 4898
# 人 1
# 真的 21
# 超级 201
# 超级 201
# 超级 201
# 4898
# 天 22
# 千年 589
# 589
# 毛主席 1173
# 曾 644
# 参观 144
# 地位 2306
# 锦绣谷 6670
# 进入 172
# 出口 1064
# 仙人洞 5118
# 洞口 5031
# 宽敞 4740
# 并不 902
# 深 1580
# 6670
# 宋仁宗 38890
# 临摹 13584
# 兰亭集序 14292
# 听说 505
# 酷爱 15082
# 王羲之 6160
# 晚上 58
# 回去 1034
# 仓桥 6063
# 直街 5201
# 溜达 1180
# 幸运 1515
# 吃 70
# 顿 2751
# 状元楼 14293
# 大餐 24197
# 排队 83
# 超长 11485
# 不敌 38891
# 幸运 1515
# 期间 817
# 网站 4468
# 愉快 581
# 退 2479
# 房间 1047
# 酒店 330
# 已经 85
# 同意 10286
# 网 2403
# 整 1465
# 事 1109
# 害得 12452
# 提前 306
# 天 22
# 房 1697
# 期间 817
# 顿 2751
# 争吵 31991
# 旋转 2857
# 跳跃 6822
# 最后 214
# 损失 11969
# 200 842
# 元 25
# 以后 213
# 果断 2923
# 放弃 1728
# 傻 5460
# 网站 4468
# 38891
# 地方 5
# 好 6
# 看点 1722
# 1722
# 道教 761
# 第一 59
# 名山 846
# 武当 11486
# 剑法 38892
# 名不虚传 813
# 38892
# 春暖花开 5557
# 5557
# 水 97
# 真的 21
# 好 6
# 清 455
# 接 1234
# 瓶 1614
# 喝 915
# 矿泉水 3539
# 好喝 6161
# 一定 44
# 玩 20
# 索道 87
# 一点 150
# 害怕 1943
# 很好 24
# 玩 20
# 6161
# 孩子 123
# 最爱 1828
# 1828
# 门票 18
# 150 906
# 大洋 5119
# 江南水乡 1152
# 横店 1751
# 唯一 310
# 夜游 1859
# 项目 184
# 精彩 591
# 衣服 899
# 可能会 2035
# 湿 3394
# 着装 21810
# 准备 561
# 21810
# 茶 971
# 溪谷 3268
# 人 1
# 适合 54
# 小孩子 997
# 玩 20
# 3268
# 夜景 254
# 美 11
# 254
# 第一 59
# 次 19
# 西湖 36
# 时 99
# 西湖 36
# 风景 12
# 体会 558
# 意境 1225
# 美 11
# 印象 217
# 西湖 36
# 演出 456
# 不远 718
# 1225
# 震撼 132
# 大马 3532
# 戏 2045
# 3532
# 亲子游 334
# 334
# 现今 5371
# 保存 414
# 最好 108
# 皇家 401
# 园林 241
# 长廊 840
# 壁画 2173
# 相当 459
# 景点 9
# 5371
# 春节 929
# 出行 420
# 929
# 瘦西湖 861
# 最好 108
# 春天 695
# 春风 8252
# 一吹 11060
# 风景 12
# 宜人 2103
# 节假日 371
# 人 1
# 太多 74
# 11060
# 位置 348
# 有点 63
# 偏 1432
# 1432
# 路过 346
# 一个 4
# 免费 137
# 经典 697
# 697
# 市区 384
# 回用 27301
# 天 22
# 一定 44
# 听 202
# 讲解 146
# 感觉 10
# 堆 2002
# 石像 5032
# 27301
# 排队 83
# 两 35
# 小时 38
# 玩 20
# 20 189
# 秒 3799
# 最多 945
# 超过 2016
# 两分 6523
# 钟 930
# 迪斯尼 1314
# 一整天 1965
# 一整天 1965
# 6523
# 人 1
# 太多 74
# 不论什么 24198
# 外观 1817
# 不错 2
# 里面 16
# 东西 96
# 维护 2418
# 不太好 1670
# 东西 96
# 翻修 5461
# 中 51
# 24198
# 月 100
# 14 452
# 日 199
# 深圳华侨城 38893
# 游 68
# 38893
# 吃 70
# 不惯 12977
# 12977
# 马戏 2606
# 2606
# 完 438
# 兵马俑 260
# 顺路 3643
# 华清宫 1566
# 西安 484
# 确实 139
# 值得 8
# 地方 5
# 一个 4
# 喜欢 40
# 历史 47
# 人 1
# 3643
# 首都 2036
# 北京 31
# 象征 1060
# 值得 8
# 看看 34
# 一个 4
# 地方 5
# 顺道 7291
# 天安门 265
# 广场 198
# 周边 379
# 游览 112
# 一下 69
# <br 3
# >n 45
# 7291
# 凉爽 1233
# 闲适 6409
# 愉悦 3360
# 6409
# 简简单单 18382
# 一个 4
# 毛泽东 1119
# 年轻 3359
# 雕塑 1271
# 积满 31992
# 很多人 1226
# 值得 8
# 31992
# 震撼 132
# 132
# 仿 2419
# 江南水乡 1152
# 感觉 10
# 人 1
# 太多 74
# 失去 3005
# 本土 10649
# 特色 60
# 10649
# 嘻嘻 4006
# 4006
# 美丽 121
# 草场美丽 38894
# 夕阳 1967
# 慢悠悠 4810
# 踱步 15083
# 小 41
# 马儿 19916
# 停下来 3708
# 漫步 795
# 小憩 6271
# 感受 131
# 重庆 2362
# 38894
# 清明节 4207
# 已经 85
# 盛 4741
# 依然 935
# 登山 491
# 戏水 3396
# 好去处 399
# <br 3
# >n 45
# 4741
# 最 33
# 初建 12978
# 明代 1057
# 朱氏 21811
# 别业 21812
# 典型 814
# 座 71
# 江南 290
# 园林 241
# 座博物馆 38895
# 园内 901
# 亭台楼阁 2817
# 曲桥 11061
# 面积 289
# 环绕 1617
# 游廊 27302
# 水榭 7635
# 曲桥 11061
# 假山 2733
# 凉亭 6064
# 假山 2733
# 亭台楼阁 2817
# 精致 675
# 可圈可点 18383
# 一些 98
# 事迹 6272
# 38895
# 明朝 1587
# 旅行家 15084
# 徐霞客 6671
# 登临 8725
# 黄山 67
# 时 99
# 赞叹 2626
# 薄 6524
# 海内外 4103
# 名山 846
# 无如 18384
# 徽 8485
# 黄山 67
# 登 680
# 黄山 67
# 天下 355
# 无山 8969
# 观止 17078
# 后人 2833
# 引申为 19917
# 五岳 489
# 归来 407
# 看山 963
# 黄山 67
# 归来 407
# 岳 882
# 印象 217
# 中的 249
# 黄山 67
# 应该 118
# 图片 1149
# 摄于 27303
# 2007 4208
# 年 28
# 冬季 1026
# 登临 8725
# 黄山 67
# 当年 418
# 黄山 67
# 之行 885
# 天气 88
# 力 1849
# 可惜 183
# 当年 418
# 西海 1184
# 大峡谷 424
# 并未 9276
# 完全 264
# 27303
# 方便 32
# 32
# 说 30
# 四川 1524
# 风景区 283
# 都会 359
# 想到 1425
# 九寨 739
# 九寨 739
# 归来 407
# 水 97
# 胡说 27304
# 九寨 739
# 水 97
# 美 11
# 一面镜子 8970
# 池子 2711
# 水 97
# 特别 29
# 夏天 181
# 阳光 570
# 照耀 4469
# 下 43
# 特别 29
# 美 11
# 27304
# 团 586
# 旅行社 2420
# 统一 2627
# 订 754
# 票 55
# 正好 493
# 赶上 483
# 20 189
# 第一 59
# 天 22
# 试运营 31993
# 大排长龙 31994
# 场景 974
# 可想而知 5842
# 同行 2682
# 单反 5843
# 拒之门外 38896
# 还好 295
# 团 586
# 暂 19918
# 存在 1953
# 导游 81
# 后 50
# 还要 344
# 换 1418
# 鞋套 2712
# 走过 798
# 桥 312
# 后 50
# 还要 344
# 回收 14294
# 换上 8486
# 鞋套 2712
# 后 50
# 排队 83
# 验票 4104
# 上桥 14295
# 上桥 14295
# 后 50
# 感觉 10
# 深深地 10287
# 坑 229
# 传说中 1293
# 全透明 10650
# 玻璃 508
# 桥面 5844
# 间隔 6823
# 一块 687
# 块 278
# 透明 3099
# 玻璃 508
# 玻璃 508
# 表面 8253
# 已经 85
# 磨 8487
# 痕 16014
# 桥下 4470
# 风景 12
# 清晰可见 11487
# 桥上 1588
# 拍 120
# 点 27
# 照片 208
# 下桥 27305
# 一点 150
# 刺激 275
# 失望 377
# 至极 6824
# 体验 126
# 次 19
# 嫌多 31995
# 造 1779
# 38896
# 动物 270
# 精神 2397
# 2397
# 不错 2
# 超大型 31996
# 公园 73
# 值得 8
# 门票 18
# 150 906
# 31996
# 走上 1735
# 坐 37
# 缆车 135
# 下来 170
# 上面 236
# 风景 12
# 不错 2
# 先 244
# 走上 1735
# 再 62
# 坐 37
# 缆车 135
# 回来 511
# 1735
# 亲眼看到 8488
# 想象 280
# 不出 2590
# 世间 7292
# 美丽 121
# 地方 5
# 8488
# 人 1
# 1
# 海洋馆 2734
# 青岛 2792
# 真的 21
# 觉得 49
# 不错 2
# 季节 308
# 2792
# 挺不错 388
# 388
# 风景美 2037
# 空气 177
# 清晰 1764
# 很好 24
# 值 527
# 再 62
# 累 109
# 点 27
# 2037
# 南山寺 3068
# 3068
# 逛 106
# 天都 2003
# 逛 106
# 完 438
# 很大 65
# 值 527
# 得来 3901
# 趟 623
# 3901
# 相当于 3147
# 条 93
# 步行街 1279
# 很多餐厅 38897
# 小吃 317
# 周边 379
# 好些 3759
# 景点 9
# 38897
# 大连 2363
# 海滨 5113
# 景点 9
# 可拍照 27306
# 27306
# 恩 3953
# 九寨沟 240
# 景色 17
# 海子 1206
# 突出 3269
# 一个 4
# 3953
# 夫子庙 587
# 秦淮河 1038
# 一带 1889
# 相对来说 4209
# 还算 649
# 不错 2
# 六月 3069
# 中旬 5845
# 艳阳天 17079
# 中午 626
# 天气 88
# 十分 259
# 炎热 4055
# 走马观花 1201
# 夫子庙 587
# 秦淮河 1038
# 游 68
# 遍 660
# 玄武湖 8971
# 泛舟 2503
# 选择 101
# 乘船 2121
# 游 68
# 秦淮 2075
# 夫子庙 587
# 景点 9
# 十分 259
# 推荐 64
# 地方 5
# 陈列 2381
# 东西 96
# 偏向 15085
# 资料 4303
# 古物 9586
# 太多 74
# 特色 60
# 秦淮河 1038
# 值得 8
# 购买 654
# 一些 98
# 当地 221
# 特色 60
# 物品 4163
# 纪念品 1363
# 价格 157
# 偏 1432
# 贵 90
# 秦淮河 1038
# 偏向 15085
# 夜晚 715
# 游览 112
# 可惜 183
# 行程 439
# 遗憾 261
# 17079
# 赞 152
# 一个 4
# 152
# 气势恢宏 2320
# 值得一看 255
# 学 1553
# 历史 47
# 知识 828
# 2320
# 中国 48
# 古代 247
# 最 33
# 壮丽 1387
# 城楼 1430
# 1430
# 超出 2591
# 预期 1988
# 真的 21
# 适合 54
# 形容 1369
# 觉得 49
# 融入 4247
# 杭州 79
# 4247
# 白河 5120
# 堡 8254
# 水库 1484
# 北京市 336
# 延庆县 6672
# 北部 3006
# 白河 5120
# 发源 7831
# 河北 5121
# 张家口 24199
# 沽源县 38898
# 先向 38899
# 南 518
# 流过 5653
# 延庆 3711
# 再 62
# 向东 5033
# 怀柔 2793
# 密云 5202
# 注入 10288
# 密云水库 5558
# 白河 5120
# 地处 1403
# 燕山 6162
# 深山 9277
# 峡谷 652
# 中 51
# 流经 8255
# 地区 980
# 美景 136
# 尤其 256
# 流经 8255
# 北京 31
# 县区 38900
# 开发 316
# 成 300
# 景区 7
# 人称 6410
# 百里 4471
# 画廊 3212
# 时间 26
# 值得 8
# 自驾 568
# 游 68
# 白河 5120
# 堡 8254
# 水库 1484
# 白河 5120
# 上游 4420
# 得名 727
# 明代 1057
# 要塞 11062
# 堡 8254
# 扼守 19919
# 白河 5120
# 峡谷 652
# 38900
# 地标 724
# 地铁 429
# 二号线 11488
# 陆家嘴 5559
# 号 151
# 出口 1064
# 不用 182
# 走 15
# 几步 3801
# 11488
# 青龙峡 9921
# 风光 179
# 不错 2
# 爬山 103
# 陡 762
# 山 66
# 清水 3678
# 秀 862
# 一边 825
# 攀岩 16015
# 蹦极 2794
# 索道 87
# 碰碰车 10651
# 射击 24200
# 娱乐 986
# 项目 184
# 有点 63
# 贵 90
# 收费 309
# 24200
# 下 43
# 黄山 67
# 景区 7
# 旅游 57
# 国线 38901
# 大巴 479
# 一直 129
# 走到 301
# 坐 37
# 索道 87
# 地方 5
# 身份证 267
# 换票 1294
# 方便 32
# 38901
# 三清山 206
# 又名 1398
# 少 125
# 华山 1182
# 丫 11489
# 山 66
# 位于 61
# 中国 48
# 江西省 5654
# 上饶市 8726
# 玉山县 11063
# 德兴市 14296
# 交界处 5462
# 玉京 10652
# 玉虚 11970
# 玉华 11064
# 峰 488
# 宛如 2251
# 道教 761
# 玉 2795
# 清 455
# 清 455
# 太 42
# 清 455
# 位尊 15086
# 神 1073
# 列坐 10289
# 山巅 7293
# 得名 727
# 玉京峰 6979
# 最高 523
# 海拔 342
# 1819.9 13585
# 米 76
# 江西 3070
# 高峰 1659
# 怀玉山 17080
# 脉 6673
# 最高峰 2713
# 信江 19920
# 源头 4472
# 三清山 206
# 道教 761
# 名山 846
# 世界 102
# 自然遗产 8727
# 世 3182
# 19920
# 放松 808
# 心境 4742
# 好去处 399
# 城市 333
# 中 51
# 小 41
# 绿洲 5122
# 5122
# 景点 9
# 较少 3361
# 3361
# 雨 374
# 中 51
# 游园 4351
# 4351
# 好好 166
# 好 6
# 166
# 迪士尼 352
# 两日游 4202
# 4202
# 东 292
# 栅 296
# 很大 65
# 一个 4
# 小时 38
# 逛 106
# 完了 1829
# ~~ 460
# 进东 27307
# 栅 296
# 坐船 532
# 渡 7468
# 80 525
# 块钱 537
# 条 93
# 船 393
# 船 393
# 最多 945
# 可坐 5747
# 人 1
# 坐 37
# O 2770
# O 2770
# 27307
# 漂亮 94
# 94
# 长城 174
# 起点 2063
# 大海 1671
# 古建 8256
# 特色 60
# 8256
# 一个 4
# 字 372
# 破 3007
# 上面 236
# 吃 70
# 东西 96
# 卫生 1707
# 差 473
# 贵 90
# 3007
# 陕西 4007
# 山西 2835
# 2015 2275
# 暑假 1140
# 孩子 123
# 出去玩 4574
# 休闲 277
# 为主 771
# 西安 484
# 之后 162
# 坐 37
# 动车 3454
# 平遥 3213
# 不错 2
# 游 68
# 乔家大院 2404
# 听说 505
# 王家大院 10290
# 有名 382
# 乔家大院 2404
# 电视剧 1799
# 捧起 31997
# 应该 118
# 王家 8489
# 大院 5034
# 南方人 5463
# 山西 2835
# 照片 208
# 手机 1016
# 里 46
# 容易 579
# 上传 6674
# 以后 213
# 机会 250
# 再上 8728
# 31997
# 自驾 568
# 安吉 5035
# 一日游 345
# 5035
# 不错 2
# 2
# 美 11
# 初见 16016
# 仙境 453
# 赞叹不已 16017
# 每个 335
# 人 1
# 控制 4210
# 不住 5372
# 尖叫 8972
# 好 6
# 美 11
# 淡季 404
# 震撼 132
# 16017
# 漂亮 94
# 尤其 256
# 赶时间 4304
# 情况下 3031
# 骑着 4056
# 自行车 756
# 慢慢 315
# 4304
# 邵 27308
# 明书院 31998
# 邵 27308
# 明书院 31998
# 31998
# 位于 61
# 北京 31
# 怀柔 2793
# 自然 222
# 条件 1641
# 很好 24
# 2793
# 方便快捷 916
# 916
# 挺 56
# 教育 904
# 意义 536
# 地方 5
# 看看 34
# 伟人 2458
# 生活 321
# 环境 84
# <br 3
# 2458
# 一家 394
# 四口 27309
# 旅行 227
# 27309
# 棒 232
# 232
# 值得 8
# 游 68
# 68
# 很好 24
# 很累 524
# 风景 12
# 美 11
# 孩子 123
# 孩子 123
# 很棒 209
# 524
# 拍照 117
# 真的 21
# 真的 21
# 很漂亮 147
# 朋友 128
# 拍 120
# 好 6
# 半天 721
# 721
# ...
# 东西 96
# 盐 3624
# 盐 3624
# 流 2354
# 汗 3907
# 风 665
# 吹干 27691
# 流 2354
# 风 665
# 吹干 27691
# 一个人 1910
# 胜利 7493
# 欢呼 15194
# 喝彩 27692
# 无需 4115
# 欢呼 15194
# 无需 4115
# 喝彩 27692
# 所谓 962
# 太阳 590
# 已经 85
# 下山 164
# 气温 2079
# 骤降 24496
# 南天门 908
# 背后 3569
# 天街 4735
# 今晚 15278
# 住 153
# 下 43
# 住宿 319
# 便宜 175
# 开口 14332
# 价 966
# 两百 6744
# 标 4590
# 间 415
# 公共厕所 13121
# 没法 2364
# 洗澡 3652
# 找 178
# 家 314
# 最后 214
# 找 178
# 120 932
# 元 25
# 晚 248
# 电暖气 39506
# 计较 17321
# 过多 3449
# 口 847
# 面包 5943
# 香肠 18608
# 穿着 2117
# 棉袄 13770
# 裹着 13771
# 被子 9401
# 睡 2427
# 闹钟 15136
# 第二 140
# 天 22
# 早上 211
# 点 27
# 39506
# 美 11
# 下雨 323
# 看到 23
# 仙境 453
# 晴天 1025
# 好玩 105
# 1025
# 再 62
# 只 107
# 玩 20
# 天 22
# 腿疼 7663
# 两 35
# 星期 7050
# 夏天 181
# 带来 1875
# 丝 3309
# 清凉 2170
# 7663
# 建议 52
# 先 244
# 坐 37
# 滑车 5241
# 烽火台 4669
# 再 62
# 爬到 509
# 十 226
# 烽火台 4669
# 下来 170
# 滑车 5241
# 买 82
# 单程 1351
# 好 6
# 5241
# 得不到 10051
# 永远 1994
# 骚动 11631
# 偏爱 7206
# 有恃无恐 12096
# 12096
# 开 233
# 往日 9675
# 沟 2285
# 线路 1252
# 终点站 3321
# 原始森林 1742
# 全部 708
# 人 1
# 箭竹 2607
# 海站 39507
# 下车 337
# 走进 1076
# 箭竹 2607
# 海 436
# 环形 6745
# 栈道 225
# 开启 7016
# 日则沟 5517
# 徒步 408
# <br 3
# >rn 14
# 箭竹 2607
# 海 436
# 英雄 2587
# 名声大噪 16216
# 无名 18609
# 李连杰 24497
# 残剑 39508
# 水面 1031
# 决斗 39509
# 场面 1935
# 湖面 577
# 进行 1175
# 放置 8515
# 飞雪 12601
# 风亭 32407
# 却 243
# 消失 4556
# 无踪 39510
# 当时 188
# 箭竹 2607
# 海 436
# 水面 1031
# 纹丝不动 39511
# 打算 1395
# 镜海 3985
# 领略到 6536
# 镜海 3985
# 风光 179
# 39511
# 五一 1390
# 假期 900
# 爱人 3417
# 小孩 496
# 一起 110
# 俩 3173
# 衢州 600
# 药王山 621
# 旅游 57
# 开车 487
# 小时 38
# 交通 176
# 便利 943
# 算是 294
# 爬山 103
# 看风景 1106
# 遇见 2030
# 瀑布 119
# 好 6
# 壮观 86
# 生态环境 1400
# 很好 24
# 吸引 595
# 游客 53
# 服务 180
# 周到 3479
# 人性化 2301
# 3479
# 人山人海 622
# 622
# 永远 1994
# 迪斯尼 1314
# 1994
# 中国人民大学 22061
# 简称 4012
# 人大 9079
# 特别 29
# 喜欢 40
# 高校 8352
# 校园环境 13122
# 干净 327
# 整洁 2426
# 浓厚 1191
# 人文 559
# 气息 238
# 22061
# 厦门 1256
# 鼓浪屿 441
# 建议 52
# 岛上 437
# 住 153
# 晚 248
# 慢慢 315
# 寻觅 10780
# 万国 11165
# 建筑 39
# 景点 9
# 联票 790
# 旅游网站 39512
# 订 754
# 39512
# 力 1849
# 1849
# 相对来说 4209
# 这种 338
# 历史 47
# 遗迹 1575
# 类 2260
# 东西 96
# 太 42
# 理解 1818
# 深意 18610
# 达到 2205
# 那种 417
# 境界 10393
# 只能 155
# 景点 9
# 游览 112
# 18610
# 风景 12
# 不错 2
# 12
# 还行 239
# 风景 12
# 还行 239
# 门票 18
# 不贵 719
# 住 153
# 附近 148
# 去走走 3591
# 3591
# 北京 31
# 剩下 2333
# 胡同 480
# 拆 5898
# 拆 5898
# 拆 5898
# 拆 5898
# 以后 213
# 胡同 480
# 游都 32408
# 没了 3215
# 32408
# 都江堰 368
# 风景区 283
# 游玩 75
# 建议 52
# 全程 467
# 步行 230
# 风景秀丽 791
# 自然风光 864
# 864
# 很棒 209
# 次 19
# 出行 420
# 420
# 身临其境 2756
# 2756
# 十一 759
# 国庆节 2240
# 朋友 128
# 自驾 568
# 水磨 18611
# 古镇 168
# 属于 669
# 羌寨 13123
# 刚进 13772
# 十月 2141
# 已有 4300
# 秋意 17322
# 汉族 2666
# 地区 980
# 古镇 168
# 说 30
# 风格 565
# 迥异 10394
# 一饱眼福 15279
# 牦牛肉 22062
# 奶糖 32409
# 腊 11166
# 排骨 7555
# 酥油茶 14466
# 汶川 9402
# 红 1352
# 李 9080
# 各色 2927
# 美食 707
# 垂涎 32410
# 眼观 24498
# 美景 136
# 口 847
# 品 2473
# 美食 707
# 尽情欢乐 39513
# 心怀 14467
# 驰骋 14468
# 39513
# 算是 294
# 无锡 2284
# 一个 4
# 标志性 618
# 景区 7
# 比较 13
# 有名 382
# 2284
# 还行 239
# 239
# 学习 1259
# 一下历史吧 39514
# 记住 2764
# 曾经 723
# 侵略 11167
# 39514
# 衢州 600
# 烂柯山 1615
# 美丽 121
# 规模 432
# 景色 17
# 比不上 5938
# 天 22
# 脊 625
# 龙门 540
# 药王山 621
# 特色 60
# 石 442
# 梁柱 4073
# 下面 506
# 洞口 5031
# 挺 56
# 壮观 86
# 游客 53
# 转转 1237
# 看看 34
# 还算 649
# 值得 8
# 5938
# 修整 9391
# 后 50
# 茶卡盐湖 2524
# 以前 305
# 规范 3214
# 专门 905
# 人 1
# 维持秩序 13124
# 景色 17
# 美 11
# 13124
# 一共 1520
# 展厅 1931
# 坑里 9403
# 兵马俑 260
# 第一 59
# 次 19
# 北京 31
# 心里 1275
# 想 80
# 实际 1796
# 见到 742
# 天安门 265
# 落差 2635
# 那种 417
# 心情 396
# 下 43
# 大雨 1607
# 人 1
# 特多 4001
# 馆内 4137
# 都是 1582
# 湿湿的 24499
# 24499
# 商 7357
# 文化 89
# 起源 8821
# 山西 2835
# 骄傲 2371
# 好多 122
# 电视剧 1799
# 取景 1475
# 院落 2808
# 很大 65
# 却 243
# 紧凑 4381
# 8821
# 北京 31
# 欢迎 2906
# 开天辟地 32309
# 天安门 265
# 北京 31
# 标志 858
# 32309
# 感觉 10
# 烧钱 27693
# 意思 454
# 27693
# 中国 48
# 近代 2725
# 文化人 20192
# 代表 806
# 鲁迅故居 3924
# 景点 9
# 免费参观 3164
# 20192
# 神圣 1809
# 布达拉宫 944
# 壮美 2660
# 感觉 10
# 2660
# 风景 12
# 无限 1214
# 好 6
# 1214
# 避暑 993
# 好去处 399
# 993
# 难忘 1310
# 1310
# 0
# 孟仑热带植物园 39515
# 真心 322
# 值得 8
# 地方 5
# 热带植物 6336
# 地方 5
# 不到 303
# 整个 124
# 植物园 1656
# 必要 521
# 尤其 256
# 景区 7
# 第二 140
# 部分 503
# 电瓶车 614
# 必要 521
# 坐 37
# 走路 743
# 真的 21
# 很累 524
# 39515
# 公园 73
# 北京 31
# 朝阳区 2691
# 青年路 39516
# 西里 10395
# 号 151
# 座 71
# 城市公园 6901
# 39516
# 群 859
# 人工 811
# 养殖 16217
# 猴子 499
# 游客 53
# 买 82
# 吃 70
# 不贵 719
# 近距离 1624
# 接触 1882
# 猴子 499
# 第一 59
# 次 19
# 开心 114
# 16217
# 家庭 637
# 游 68
# 开心 114
# 637
# 仿古 1842
# 建筑 39
# 感受一下 898
# 当年 418
# 恢宏 4466
# 气势 689
# 4466
# 黄山 67
# 风景 12
# 真的 21
# 太美 477
# 值得 8
# 来一次 6825
# 次 19
# 看见 297
# 云海 351
# 有点 63
# 遗憾 261
# 爬山 103
# 辛苦 1136
# 建议 52
# 太小 2268
# 小孩 496
# 6825
# 很早 2612
# 听说 505
# 看过 807
# 黄山 67
# 天下 355
# 无山 8969
# 10 113
# 月中 3209
# 旬 4295
# 老婆 2723
# 一起 110
# 爬 78
# 一次黄山 18612
# 前 156
# 天 22
# 翡翠谷 9081
# 景色 17
# 画 629
# 真的 21
# 美的 366
# 无 686
# 碧绿色 20193
# 水潭 10777
# 水质 2081
# 农夫山泉 11168
# 还好 295
# 第二 140
# 天 22
# 爬山 103
# 上山 141
# 坐 37
# 缆车 135
# 爬山 103
# 花 192
# 小时 38
# 中午 626
# 太阳 590
# 不错 2
# 景色 17
# 说什么 4019
# 没用 6082
# 知道 91
# 始信峰 6106
# 美丽 121
# 20193
# 融合 2597
# 藏 1433
# 汉 4509
# 佛教 512
# 特色 60
# 场 1029
# 佛教文化 2512
# 之旅 380
# 4509
# 人间仙境 1280
# 般 273
# 云里雾里 8577
# 奇石林 27694
# 27694
# 中国 48
# 一个 4
# 地方 5
# 地方 5
# 核心 1698
# 地方 5
# 1698
# 知道 91
# 挺 56
# 美的 366
# 风光 179
# 不错 2
# 人潮 3545
# 拥挤 1168
# 吃到 2784
# 美味 3158
# 鸭血粉丝 7179
# 好吃 326
# 7179
# 杭州 79
# 地方 5
# 值得 8
# 推荐 64
# 79
# 东 292
# 福山 5779
# 岛 545
# 环岛 5987
# 看到 23
# 大风车 24500
# 实地 7207
# 照片 208
# 美 11
# 24500
# 童年 2282
# 记忆 1083
# 总是 1090
# 美好 562
# 希望 360
# 永远 1994
# 记忆 1083
# 中的 249
# 样子 631
# 2282
# 比较简单 20194
# 公园 73
# 长安街 2221
# 沿线 6352
# 20194
# 轻松 1035
# 惬意 530
# 出游 252
# 1035
# 增长 4185
# 见识 2336
# 4185
# 红门 1005
# 入口 658
# 天外村 2624
# 入口 658
# 上泰山 12602
# 此时 2880
# 总会 4711
# 汇总 27695
# 南天门 908
# 南天门 908
# 爬上 1304
# 山顶 133
# 山顶 133
# 遗憾 261
# 金灿灿 9315
# 大字 3414
# 太阳 590
# 下 43
# 太美 477
# 登上 677
# 山顶 133
# 激动 1696
# 27695
# 灵隐寺 634
# 带着 325
# 诚心 9925
# 拜佛 2187
# 香火 973
# 顶旺 39517
# 39517
# 温泉 560
# 560
# 最终 2762
# 失望 377
# 2762
# 浙西 6805
# 大峡谷 424
# 日 199
# 自驾游 1117
# 6805
# 里面 16
# 山脚下 1135
# 栈道 225
# 外 369
# 走 15
# 一路 149
# 特别 29
# 幽静 879
# 湖水 688
# 颜色 871
# 很漂亮 147
# 水 97
# 里面 16
# 钙化 6746
# 树枝 8314
# 造型 1427
# 别致 2634
# 拍出 3387
# 超 340
# 预期 1988
# 好 6
# 片片 5978
# 8314
# 风味 1186
# 水 97
# 美 11
# 建筑 39
# 美 11
# 严寒 12603
# 冬天 223
# 爬上 1304
# 108 4098
# 级 286
# 台阶 431
# 看到 23
# 惊喜 821
# 12603
# 不错 2
# 2
# 西湖 36
# 周边 379
# 美 11
# 比较 13
# 地方 5
# 看看 34
# 时间 26
# 就坐 3777
# 船上 2174
# 三潭 3565
# 映 2393
# 月 100
# 岛上 437
# 走走 411
# 不错 2
# 之后 162
# 再 62
# 外边 5019
# 骑 1255
# 共享 7712
# 单车 4258
# 外围 2742
# 游玩 75
# 一下 69
# 挺好 161
# 选择 101
# 7712
# 冬天 223
# 金顶 1421
# 漂亮 94
# 日出 138
# 白雪 4102
# 云海 351
# 远望 4432
# 贡嘎 17323
# 雪山 942
# 17323
# good 7201
# 7201
# 风景 12
# 很好 24
# 24
# 月牙泉 1177
# 水 97
# 沙漠 794
# 增添 3533
# 色彩 1357
# 听说 505
# 泉水 1757
# 早上 211
# 用水 9700
# 注入 10288
# 知道 91
# 真假 8551
# 景色 17
# 美 11
# 以前 305
# 听过 5990
# 月牙泉 1177
# 首歌 7546
# 次会 32411
# 唱 2752
# 32411
# 前山 1238
# 道教 761
# 圣地 673
# 后山 750
# 佛教 512
# 场所 917
# 算是 294
# 两 35
# 景区 7
# 门票 18
# 景色 17
# 前山 1238
# 爬山 103
# 山路 678
# 水 97
# 主要 104
# 人文景观 1551
# 后山 750
# 景色 17
# 美 11
# 有山有水 1366
# 上山路 9264
# 一路 149
# 溪水 1537
# 相伴 6187
# 青城 1863
# 天下 355
# 幽 1410
# 名不虚传 813
# 9264
# 脚步 3629
# 来到 197
# 永定 4017
# 土楼 1187
# 永定 4017
# 土楼 1187
# 2007 4208
# 年 28
# 批准 3224
# 世界 102
# 文化遗产 1084
# 历史悠久 1446
# 风格 565
# 独特 490
# 客家 10781
# 民居 1434
# 建筑群 1272
# 客家 10781
# 土楼 1187
# 扬名天下 16213
# 方圆 8249
# 世界 102
# 神奇 592
# 古朴 964
# 壮观 86
# 美丽 121
# 震撼 132
# 人心 5331
# 博得 27696
# 神秘 894
# 东方 1841
# 古城堡 32412
# 全县 27697
# 圆楼 27698
# 360 4605
# 座 71
# 方楼 27411
# 4000 6353
# 余 970
# 座 71
# 32412
# 地方 5
# 设置 3322
# 不合理 4851
# 根本 602
# 走 15
# 完 438
# 电瓶车 614
# 买了 363
# 票 55
# 只 107
# 送到 2750
# 山顶 133
# 直接 111
# 送 1284
# 山下 603
# 中途 2118
# 景点 9
# 买了 363
# 门票 18
# 加 792
# 电瓶车 614
# 票 55
# 亏死 39518
# 门口 158
# 出口 1064
# 工作人员 434
# 态度 1440
# 很差 2884
# 39518
# 值得 8
# 一定 44
# 找 178
# 讲解 146
# 只能 155
# 走马观花 1201
# 1201
# 普通 797
# 一个 4
# 景点 9
# 觉得 49
# 太 42
# 吸引 595
# 走 15
# 西 276
# 环线 5300
# 路过 346
# 走走 411
# 玩玩 983
# 必要 521
# 太 42
# 放在心上 39519
# 重点 486
# 东边 2717
# 山峰 683
# 39519
# 北京 31
# 31
# 风景 12
# 美 11
# 尤其 256
# 傍晚 952
# 后 50
# 夜深 32413
# 静 2377
# 月明星稀 39520
# 自由 2023
# 惬意 530
# 39520
# 扬州 1513
# 标志性 618
# 景点 9
# 与其说是 17324
# 一个 4
# 风景区 283
# 一个 4
# 湿地 667
# 公园 73
# 水清 8578
# 17324
# 藏传佛教 1546
# 心脏 5760
# 拉萨 1456
# 中心 426
# 大昭寺 914
# 布局 1468
# 方位 9048
# 汉地 32414
# 佛教 512
# 寺院 933
# 主殿 9701
# 坐 37
# 东面 5332
# 西 276
# 主殿 9701
# 高 92
# 层 313
# 两侧 1364
# 列有 39521
# 配殿 6747
# 布局 1468
# 结构上 39522
# 再现 3276
# 佛教 512
# 中 51
# 曼陀罗 32415
# 坛城 22063
# 宇宙 12097
# 理想 2929
# 模式 4779
# 三楼 8822
# 拍 120
# 金顶 1421
# 俯瞰 630
# 寺前 15071
# 广场 198
# 远眺 1298
# 布达拉宫 944
# 39522
# 漂亮 94
# 环境 84
# 好 6
# 漂亮 94
# 环境 84
# 好 6
# 94
# 挺不错 388
# 景区 7
# 车 145
# 选择 101
# 经典 697
# 景点 9
# 参观 144
# 拥挤 1168
# 舒服 320
# 景色 17
# 美丽 121
# 1168
# 适合 54
# 小孩子 997
# 初步 18613
# 了解 293
# 不用 182
# 跑来跑去 13125
# 18613
# 绍兴 812
# 书圣 9576
# 故里 1429
# 书 1442
# 圣王 24501
# 羲 32416
# 故里 1429
# 里面 16
# 王羲之 6160
# 蔡元培 8823
# 故居 628
# 戒 13115
# 珠 5704
# 讲寺 16218
# 蕺 17325
# 题 3680
# 扇 4921
# 桥 312
# 探花 39523
# 台门 9404
# 太平天国 11632
# 壁画 2173
# 中间 555
# 穿插 14469
# 河流 2586
# 逛 106
# 故里 1429
# 门票 18
# 逛 106
# 展馆 2178
# 需要 77
# 买 82
# 门票 18
# 门票 18
# 60 584
# 元 25
# 人 1
# 不算 469
# 安静 400
# 祥和 4814
# 石桥 2564
# 流水 1645
# 充满 1085
# 浓郁 1786
# 江南水乡 1152
# 感觉 10
# 周恩来纪念馆 18545
# 途中 1486
# 发现 216
# 马路上 11633
# 指示牌 2508
# 显示 2599
# 书圣 9576
# 故里 1429
# 参观 144
# 完 438
# 纪念馆 3323
# 继续 835
# 往北 4585
# 找寻 16219
# 书圣 9576
# 故里 1429
# 找到 544
# 故里 1429
# 边缘 4991
# 地带 3839
# 时间 26
# 限制 2873
# 体力 347
# 限制 2873
# 仔细 1661
# 逛 106
# 书圣 9576
# 故里 1429
# 建筑 39
# 保留 965
# 原始 1296
# 风貌 1558
# 值得 8
# 39523
# 游 68
# 景点 9
# 68
# 人 1
# 人 1
# 人 1
# 人 1
# 人 1
# 人 1
# 人 1
# 1
# 不错 2
# 2
# 不错 2
# 不错 2
# 不错 2
# 不错 2
# 不错 2
# 不错 2
# 不错 2
# 不错 2
# 不错 2
# 不错 2
# 不错 2
# 不错 2
# 不错 2
# 不错 2
# 不错 2
# 不错 2
# 不错 2
# 不错 2
# 不错 2
# 不错 2
# 不错 2
# 不错 2
# 不错 2
# 2
# 风景如画 1385
# 三潭 3565
# 映 2393
# 月 100
# 下次 212
# 还要 344
# 3565
# 丽江 447
# 人 1
# 心目中 7707
# 艳遇 3192
# 天地 2533
# 艳遇 3192
# 天长地久 27699
# 事情 1322
# 期待 726
# 旅途 2679
# 中 51
# 遇到 531
# 爱 471
# 倒 1131
# 真不 4485
# 带着 325
# 爱人 3417
# 丽江 447
# 走 15
# 喧闹 3462
# 古城 159
# 街头 9658
# 买 82
# 两 35
# 块 278
# 鲜花 2773
# 饼 3473
# 听 202
# 路边 1159
# 小店 582
# 里 46
# 鼓点 32326
# 晚间 11634
# 温和 11169
# 风拂 32417
# 姑娘 3343
# 发香 32418
# 倒 1131
# 有种 1394
# 真切 12604
# 生活 321
# 别处 5888
# 感觉 10
# 32418
# 天 22
# 安排 615
# 时间 26
# 紧凑 4381
# 颐和园 421
# 做客 22064
# 车 145
# 时 99
# 下午 193
# 点 27
# 没想到 1239
# 当天 624
# 星期五 17326
# 的路 3720
# 堵 2250
# 厉害 1535
# 堵 2250
# 一个 4
# 钟头 10396
# 天上 2326
# 雨 374
# 下得 16220
# 最后 214
# 狠狠 11626
# 牙 4943
# 客车 7380
# 走 15
# 七百 9405
# 米 76
# 来到 197
# 地铁口 7020
# 换乘 1800
# 两 35
# 站 169
# 后 50
# 水立方 1158
# 已经 85
# 晚上 58
# 点钟 4263
# 星期五 17326
# 晚上 58
# 水立方 1158
# 开放 279
# 大老远 9082
# 赶来 16221
# 却 243
# 开放 279
# 人 1
# 无奈 2791
# 看着 349
# 安全门 39524
# 关好 27700
# 安全门 39524
# 走上 1735
# 原来 538
# 二楼 3489
# 雅座 39525
# 喝喝 11113
# 咖啡 3127
# 咖啡厅 8959
# 里头 5935
# 看到 23
# 水立方 1158
# 内景 20195
# 赶紧 2972
# 没人 1545
# 拍 120
# 几张 1899
# 心满意足 18614
# 离开了 5566
# 39525
# 中巴车 6702
# 泰山 116
# 太 42
# 脏 2167
# 6702
# 冬日 3432
# 空气 177
# 里 46
# 夹杂着 13773
# 很大 65
# 煤烟 39526
# 味 1463
# 下午 193
# 家家户户 13126
# 烧 2355
# 坑 229
# 烟雾 4785
# 缭绕 866
# 39526
# 值得 8
# 小朋友 443
# 反复 10052
# 来玩 2658
# 地方 5
# 一直 129
# 玩到 3409
# 10052
# 科技馆 4138
# 一日游 345
# 4138
# 位置 348
# 浙江省 1404
# 杭州市 4079
# 西 276
# 湖区 2642
# 风景 12
# 名胜区 937
# 龙井路 13774
# 号 151
# 西湖 36
# 位于 61
# 浙江省 1404
# 杭州市 4079
# 西面 4031
# 中国 48
# 大陆 4204
# 首批 2087
# 国家 196
# 重点 486
# 风景 12
# 名胜区 937
# 中国 48
# 十 226
# 风景名胜 2802
# 中国 48
# 大陆 4204
# 主要 104
# 观赏性 4652
# 淡水 8353
# 湖泊 1104
# 现今 5371
# 世界遗产名录 4944
# 中 51
# 少数 4592
# 中国 48
# 唯一 310
# 一个 4
# 湖泊 1104
# 类 2260
# 文化遗产 1084
# 西湖 36
# 面 526
# 环山 3618
# 面积 289
# 约 285
# 13774
# 不错 2
# 不错 2
# 不错 2
# 吃 70
# 认真 2669
# 2669
# 人 1
# 少 125
# 125
# 方便 32
# 32
# 家人 646
# 出行 420
# 646
# 孩子 123
# 們 13705
# 天地 2533
# 13705
# 雷峰塔 583
# 景区 7
# 风景 12
# 不错 2
# 四处 5411
# 绿荫 7202
# 环绕 1617
# 7202
# 肯定 659
# 推荐 64
# 大昭寺 914
# 进藏 14440
# 14440
# 中华圣公会 27701
# 教堂 1556
# 北京 31
# 西城 5518
# 区 220
# 佟麟阁路 32419
# 教堂 1556
# 中华圣公会堂 39527
# 南沟沿 39528
# 救主 32420
# 堂 2885
# 建于 1538
# 1907 27702
# 年 28
# 圣公会 39529
# 北京 31
# 兴建 2368
# 第一 59
# 教堂 1556
# 39529
# 2016 1581
# 年 28
# 月 100
# 30 191
# 号 151
# 岳麓山 1065
# 长沙 1325
# 1581
# 周庄 1771
# 江南水乡 1152
# 特色 60
# 门票 18
# 有点 63
# 小 41
# 贵 90
# 小桥流水 1017
# 值得 8
# 游玩 75
# 1771
# 水木清华 13775
# 心中 1413
# 一个 4
# 情节 4557
# 第一 59
# 次 19
# 时 99
# 感叹 954
# 一个学校 24502
# 足足 5490
# 逛 106
# 一整天 1965
# 清华 2799
# 氛围 839
# 每一处 4353
# 建筑 39
# 颗 1350
# 灵性 7713
# 假期 900
# 学校 1192
# 教室里 39530
# 人 1
# 清 455
# 真的 21
# 刻苦 39531
# 高晓松 27703
# 说 30
# 名牌大学 21967
# 培养 7924
# 国之 27704
# 栋梁 27705
# 地方 5
# 高兴 1924
# 看到 23
# 祖国 2440
# 栋梁 27705
# 来自 2051
# 环境 84
# 最 33
# 近几年 5319
# 清华 2799
# 需要 77
# 检查 5242
# 身份证 267
# ~~~~ 3584
# 还要 344
# 排 409
# 好几 763
# 小时 38
# 队 1297
# 高校 8352
# 应该 118
# 清静 1727
# 地方 5
# 现在 72
# 却 243
# 活生生 16222
# 成 300
# 一个 4
# 旅游景点 940
# 旅游 57
# 孩子 123
# 家长 4412
# 家长 4412
# 39531
# 一个 4
# 想去 386
# 地方 5
# 一个 4
# 泡 2163
# 想 80
# 泡 2163
# 温泉 560
# 2163
# 整体 378
# 感觉 10
# 很好 24
# 江南 290
# 风格 565
# 拍照 117
# 什么的 9052
# 妥妥 10782
# 10782
# 童梦 27706
# 27706
# 西樵山 5165
# 座 71
# 具有 700
# 四万五千 27707
# 万年 3282
# 历史 47
# 死火山 17327
# 直径 6586
# 公里 163
# 面积 289
# 14 452
# 平方公里 1142
# 海拔 342
# 346 18615
# 米 76
# 主峰 1527
# 科峰 39532
# 海拔 342
# 344 39533
# 米 76
# 西樵山 5165
# 风景 12
# 资源 1374
# 丰富 476
# 72 4739
# 座 71
# 奇峰 2019
# 36 5316
# 岩洞 5519
# 232 20196
# 眼 1933
# 清泉 5619
# 28处 39534
# 飞 870
# 瀑 810
# 10 113
# 景区 7
# 白云洞 17328
# 景区 7
# 黄飞鸿狮艺武术馆 39535
# 南海 1583
# 观音 681
# 宝峰 39536
# 寺 519
# 景区 7
# 碧玉 10397
# 洞 468
# 景区 7
# 天湖 5944
# 景区 7
# 九龙 2227
# 岩 1401
# 景区 7
# 翠岩 20197
# 景区 7
# 石燕岩 39537
# 景区 7
# 桃花园 16223
# 景区 7
# 东西 96
# 天湖 5944
# 众多 751
# 名胜古迹 3550
# 湖 224
# 泉 1723
# 涧 3142
# 岩 1401
# 壁 2293
# 潭 1785
# 台 1220
# 点缀 3211
# 其间 3018
# 39537
# 刚刚 2376
# 一个 4
# 大大的 3287
# 空地 6309
# 挂 2188
# 一些 98
# 布匹 22065
# 里 46
# 进 186
# 一些 98
# 染坊 4587
# 中的 249
# 工作 1092
# 环境 84
# 一些 98
# 宏 6595
# 染 6590
# 布匹 22065
# 工具 6667
# 22065
# 不错 2
# 2
# 灵验 4866
# 大佛 647
# 很漂亮 147
# 一定 44
# 要来 1217
# 4866
# 美的 366
# 副 2824
# 画 629
# 太 42
# 仙 1827
# 三清山 206
# 位于 61
# 江西省 5654
# 上饶市 8726
# 玉山县 11063
# 德兴市 14296
# 交界处 5462
# 玉京峰 6979
# 最高峰 2713
# 海拔 342
# 1819.9 13585
# 米 76
# 道教 761
# 名山 846
# 南边 3660
# 坐 37
# 索道 87
# 西面 4031
# 上山 141
# 空气 177
# 好 6
# 没话说 4977
# 奇石 2292
# 大大小小 2556
# 直 2409
# 入 299
# 眼帘 13054
# 犹如 1479
# 幅 941
# 仙境 453
# 山水画 3691
# 14296
# 雪 494
# 日子 2083
# 配得上 17308
# 名称 3181
# 两 35
# 天 22
# 雪 494
# 知道 91
# 17308
# 优惠 594
# 次 19
# 游玩 75
# 594
# 还行 239
# 人文 559
# 景点 9
# 讲解 146
# 带着 325
# 看不出 3645
# 3645
# 圆明园 556
# 黄昏 5233
# 冬天 223
# 夕阳西下 3986
# 觉得 49
# 荒凉 3987
# 凄美 7381
# 觉得 49
# 没什么 130
# 逛 106
# 头 819
# 7381
# 江南 290
# 特色 60
# 小桥流水 1017
# 北方人 5705
# 一定 44
# 要来 1217
# 看看 34
# 5705
# 天涯海角 2276
# 2276
# 现在 72
# 已经 85
# 全 343
# 忘记 1373
# 只 107
# 知道 91
# 庐山 720
# 漂亮 94
# 1373
# 宁海 7183
# 梁黄山 39538
# 浙东 6331
# 大峡谷 424
# 纠结 6887
# 好久好久 16144
# 恩施 6748
# 大峡谷 424
# 浙北 15258
# 大峡谷 424
# 三峡 3763
# 峡谷 652
# 类 2260
# 景色 17
# 应该 118
# 相当 459
# 有点 63
# 倾向 18616
# 于去 39539
# 梁皇山 20198
# 前童 8579
# 古镇 168
# 碰到 1557
# 搞笑 7639
# 导游 81
# 说 30
# 导游 81
# 只能 155
# 算 679
# 向导 6596
# 后 50
# 真正 481
# 决定 939
# 梁黄山 39538
# 梁皇山 20198
# 古称 3689
# 位于 61
# 浙江 1130
# 宁波 924
# 宁海县 39540
# 前童镇 39541
# 境内 1299
# 宁海西站 32421
# 前 156
# 童 17329
# 中巴 5674
# 梁皇山 20198
# 向导 6596
# 带领 2948
# 下 43
# 直接 111
# 下行 4510
# 门票 18
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-81d9befb4a93> in <module>()
#     214 #     data_word['significant_key_{}'.format(_)] = data_word['words'].apply(lambda x : contain(x, key))
#     215
# --> 216 data_word = data_word_feature(data_word, feature_word = 'words')
#     217 data = pd.merge(data, data_word.drop(['words'], axis = 1), on = 'Id', how = 'left')
#     218
#
# <ipython-input-8-81d9befb4a93> in data_word_feature(data_word, feature_word)
#     140
#     141     data_word['word_len_'+ feature_word] = data_word[feature_word].apply(lambda x : words_len(x))
# --> 142     data_word['word_max_'+ feature_word] = data_word[feature_word].apply(lambda x : words_to_max(x, dictionary))
#     143     data_word['word_std_'+ feature_word] = data_word[feature_word].apply(lambda x : words_to_std(x, dictionary))
#     144     data_word['word_sum_'+ feature_word] = data_word[feature_word].apply(lambda x : words_to_sum(x, dictionary))
#
# c:\users\demonsong\appdata\local\programs\python\python36\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-8-81d9befb4a93> in <lambda>(x)
#     140
#     141     data_word['word_len_'+ feature_word] = data_word[feature_word].apply(lambda x : words_len(x))
# --> 142     data_word['word_max_'+ feature_word] = data_word[feature_word].apply(lambda x : words_to_max(x, dictionary))
#     143     data_word['word_std_'+ feature_word] = data_word[feature_word].apply(lambda x : words_to_std(x, dictionary))
#     144     data_word['word_sum_'+ feature_word] = data_word[feature_word].apply(lambda x : words_to_sum(x, dictionary))
#
# <ipython-input-8-81d9befb4a93> in words_to_max(word, dictionary)
#      78         for word in words:
#      79             if word in dictionary.keys():
# ---> 80                 print(word, dictionary[word])
#      81                 data.append(dictionary[word])
#      82             else: data.append(0)
#
# c:\users\demonsong\appdata\local\programs\python\python36\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     374             is_child = (not self._is_master_process())
#     375             # only touch the buffer in the IO thread to avoid races
# --> 376             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     377             if is_child:
#     378                 # newlines imply flush in subprocesses
#
# c:\users\demonsong\appdata\local\programs\python\python36\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# c:\users\demonsong\appdata\local\programs\python\python36\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     389                                  copy_threshold=self.copy_threshold)
#     390             data.group = group
# --> 391         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     392
#     393     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket._send_copy()
#
# c:\users\demonsong\appdata\local\programs\python\python36\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
# 情感分析
train_senti = pd.read_csv(model_path + "train_sentiment.csv")
if testFileExist: 
    test_senti = pd.read_csv(model_path + "predict_sentiment.csv")
    data_senti = pd.concat([train_senti, test_senti])
else:
    data_senti = train_senti
    
data = pd.merge(data, data_senti, on = 'Id', how = 'left')
data.head()

# %%
# 情感分析
train_senti = pd.read_csv(model_path + "train_sentiment_self.csv")
if testFileExist:
    test_senti = pd.read_csv(model_path + "predict_sentiment_self.csv")
    data_senti = pd.concat([train_senti, test_senti])
else:
    data_senti = train_senti
    
data = pd.merge(data, data_senti, on = 'Id', how = 'left')
data.head()

# %%
# 地点分析
train_address = pd.read_csv(model_path + 'train_address.csv')
if testFileExist:
    test_address = pd.read_csv(model_path + 'predict_address.csv')
    data_address = pd.concat([train_address, test_address])
else:
    data_address = train_address

def max_address(address, dictionary):
    address = address[1:-1]
    address = address.split(';')
    if len(address) == 0: return ''
    data = []
    for add in address:
        if add in dictionary: data.append(dictionary[add])
        else: data.append(0)
    return np.max(data)

def sum_address(address, dictionary):
    address = address[1:-1]
    address = address.split(';')
    if len(address) == 0: return ''
    cnt = 0
    for add in address:
        if add in dictionary: cnt += 1
    return cnt

def ratio_address(address, dictionary):
    address = address[1:-1]
    address = address.split(';')
    if len(address) == 0: return ''
    cnt = 0
    for add in address:
        if add in dictionary: cnt += 1
    return cnt / len(address)


# top 100 的旅游景区
address_all = get_words(data_address, feature='address_list')
word_num, count, dictionary, reverse_dictionary = build_dataset(address_all, vocabulary_size=100)
data_address['address_all_max'] = data_address['address_list'].apply(lambda x : max_address(x, dictionary))
data_address['address_all_sum'] = data_address['address_list'].apply(lambda x : sum_address(x, dictionary))
data_address['address_all_ratio'] = data_address['address_list'].apply(lambda x : ratio_address(x, dictionary))

# 差评 旅游景区
address = get_neg_words(pd.merge(data_address, data[['Id', 'Score']], on = 'Id', how = 'left'), feature='address_list')
word_num_neg, count_neg, dictionary_neg, reverse_dictionary_neg = build_dataset(address, vocabulary_size=100)
print(len(address))
print(count)
data_address['address_neg_all'] = data_address['address_list'].apply(lambda x : max_address(x, dictionary_neg))
data_address['address_neg_sum'] = data_address['address_list'].apply(lambda x : sum_address(x, dictionary_neg))
data_address['address_neg_ratio'] = data_address['address_list'].apply(lambda x : ratio_address(x, dictionary_neg))

del data_address['address_list']
data_address.head(100)
data = pd.merge(data, data_address,  on = 'Id', how = 'left')

# %%
# 载入hankcs分词 情绪窗口
senti_window_hankcs = pd.read_csv(model_path + 'data_senti_window_hancks.csv')
senti_window_hankcs.head()

data = pd.merge(data, senti_window_hankcs, on = 'Id', how = 'left')

# 载入结巴分词 情绪窗口
senti_window_jieba = pd.read_csv(model_path + 'data_senti_window_jieba.csv')
senti_window_jieba.head()

data = pd.merge(data, senti_window_jieba, on = 'Id', how = 'left')

# %%
# 某个词时候出现过
def wordExist(discuss, word = ''):
    return 1 if word in discuss else 0

data['word_tijian'] = data['Discuss'].apply(lambda x : wordExist(x, '体检'))

# %%
data.head()

# %%
# 属性统计
train_property = pd.read_csv(model_path + 'train_property.csv')
test_property = pd.read_csv(model_path + 'predict_property.csv')

data_property = pd.concat([train_property, test_property])
data_property_describe = data_property.describe()
data_property_describe.head()

# %%
columns = data_property_describe.columns
filter_columns = []
for col in columns:
    if data_property_describe.loc['std', col] > 0:
        filter_columns.append(col)
        
filter_columns.append('Id')
data = pd.merge(data, data_property[filter_columns], on = 'Id', how = 'left')

# %%
# 余弦相似度
# data_similarity = pd.read_csv(model_path + 'data_similarity.csv')
# data_similarity.head()

# data = pd.merge(data, data_similarity, on = 'Id', how = 'left')

# %%
# 加载词向量
data_vector = pd.read_csv(model_path + 'data_vector.csv')
data_vector.describe()

data = pd.merge(data, data_vector, on = 'Id', how = 'left')

# %%
# 弱模型的特征 无效果
# data = pd.merge(data, merge('train_ridge', 'doufu'), on = 'Id', how = 'left')

# data = pd.merge(data, merge('train_ridge', '1'), on = 'Id', how = 'left')
# data = pd.merge(data, merge('train_ridge', '2'), on = 'Id', how = 'left')
# data = pd.merge(data, merge('train_ridge', '3'), on = 'Id', how = 'left')
# data = pd.merge(data, merge('train_ridge', '4'), on = 'Id', how = 'left')

# data = pd.merge(data, merge('train_lasso', '1'), on = 'Id', how = 'left')
# data = pd.merge(data, merge('train_lasso', '2'), on = 'Id', how = 'left')
# data = pd.merge(data, merge('train_lasso', '3'), on = 'Id', how = 'left')
# data = pd.merge(data, merge('train_lasso', '4'), on = 'Id', how = 'left')

# %%
data.head()

# %%
# 删除 discuss
del data['Discuss']

# %%
if not testFileExist:
    data.to_csv(model_path + 'data_sub.csv', index = False)
    print('persist done...')
else:
#     data_sub = pd.read_csv(model_path + '/subset12/data_sub.csv')
#     data = pd.concat([data, data_sub])
    data.to_csv(model_path + 'data.csv', index = False)
    print(data.info())

# %%
print(data.info())

# %%
# 划分数据
def split_data(data, label):
    data_classify_5 = data.copy()
    data_classify_5['Score'].ix[(data_classify_5['Score'] != label) & (data_classify_5['Score'] != -1)] = 0
    data_classify_5['Score'].ix[data_classify_5['Score'] == label] = 1
    data_classify_5.to_csv('../input/multi2binary/' + 'data_{}.csv'.format(label), index = False)
    print('done...')

for i in range(1, 6):
    split_data(data, i)
